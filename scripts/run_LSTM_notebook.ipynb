# %% [markdown]
# ## Basic-ish LSTM Model

# %% [markdown]
# This script is an implementation of a fairly basic LSTM model.  This can be run with Grasser's duplicated data or the full data set (which includes the scraped data and does not contain review duplicates).
#
# Here are the details of the model:
# - It uses 300-dimension, trainable embedding initialized to the GloVe vectors
# - It uses a 2-layer, birectional recurrent network
# - The final layer is a linear layer that takes 300 inputs and outputs 3 dimensions
#
# The model is trained for 30 epochs and the model with the highest Cohen's Kappa is saved and evaluated on the test data.  Additional implementation details are provided througout the script.

# %% [markdown]
# ##### Note: This script is meant to be run on Google Colab and assumes a particular drive file structure.  This may not have been perfectly maintained in moving the repository to git.

# %% [markdown]
# ### Access Google Drive

# %%
from google.colab import drive
#drive may already be mounted. allows access to drive data
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Import our scripts

# %%
import sys
sys.path.append('./drive/MyDrive/drugproject/2_scripts')

from create_dataloader import get_dataloader
from collate import make_collate_rnn, make_collate_rnn_lemmas, make_collate_plus
from Trainer import Trainer
from Evaluator import Evaluator
from ModelContext import ModelContext
from Plotter import Plotter
from Models import BasicLSTM
# from Evaluator import Evaluator
# Out:
# No module named 'boto3'
# No module named 'boto3'

# %% [markdown]
# #### Import torch and other packages

# %%
from torchtext.vocab import Vocab, GloVe
from torch.utils.data.dataset import random_split
from torch import nn
from torch import optim
from torch.nn.utils.rnn import pad_sequence, pad_packed_sequence, pack_padded_sequence
import torch.nn.functional as F

from collections import Counter
from csv import reader
import json
import time
import random
import numpy as np

# %% [markdown]
# Set up seed and cuda.

# %%
SEED = 6624 # Specify a seed for reproducability
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(53113)
torch.backends.cudnn.deterministic = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Set parameters for run

# %% [markdown]
# data_set must be set to one of ("full", "dev", "grasser")

# %%
data_set = "dev"
lemmas = False
weights = True
additional_text_features = []

# %%
DATA = './drive/MyDrive/drugproject/3_data'

RESULTS_DIR = './drive/MyDrive/drugproject/4_results'

if data_set == "dev":
    TRAIN_FILE = f'{DATA}/grasser_data_for_lstm/train_small_df.csv'
    VALID_FILE = f'{DATA}/grasser_data_for_lstm/valid_small_df.csv'
    TEST_FILE = f'{DATA}/grasser_data_for_lstm/test_small_df.csv'
    RESULT_NAME = "basic_lstm_small"
    BATCH_SIZE = 2
    LOG_INTERVAL = 10
    VOCAB_PATH = './drive/MyDrive/drugproject/3_data/vocabs/full_vocab.json'
elif data_set == "grasser":
    TRAIN_FILE = f'{DATA}/grasser_data_for_lstm/train_full_df.csv'
    VALID_FILE = f'{DATA}/grasser_data_for_lstm/valid_full_df.csv'
    TEST_FILE = f'{DATA}/grasser_data_for_lstm/test_full_df.csv'  
    RESULT_NAME = 'basic_lstm_grasser'
    LOG_INTERVAL = 100
    BATCH_SIZE = 128
    VOCAB_PATH = './drive/MyDrive/drugproject/3_data/vocabs/grasser_vocab.json'
elif data_set == "full"
    TRAIN_FILE = f'{DATA}/grasser_data_for_lstm/train_fi.csv'
    VALID_FILE = f'{DATA}/grasser_data_for_lstm/valid_grasser_data.csv'
    TEST_FILE = f'{DATA}/grasser_data_for_lstm/test_grasser_data.csv'  
    RESULT_NAME = 'basic_lstm_full'
    LOG_INTERVAL = 100
    BATCH_SIZE = 128
    VOCAB_PATH = './drive/MyDrive/drugproject/3_data/vocabs/full_vocab.json'

if weights:
    RESULT_NAME += '_weights'

if lemmas:
    VOCAB_PATH = VOCAB_PATH[:-4] + '_lemmas.json'
    RESULT_NAME += '_lemmas'

for col in additional_text_features:
    RESULT_NAME += ('_' + col)

SHUFFLE = True

# %% [markdown]
# #### Load vocab
#
# Our vocabs are already created and saved as json files - this is necessary because our tokenizer is very slow.

# %%
with open(VOCAB_PATH, "r") as f:
    counter = json.loads(f.read())

counter = Counter(counter)
review_vocab = Vocab(counter, min_freq=100)

# %% [markdown]
# ### Load Dataloader

# %%
if lemmas:
    collate_fn = make_collate_rnn_lemmas(review_vocab, device=device)
else:
    collate_fn = make_collate_rnn(review_vocab, device=device)

optional_cols = []
encoding_cols = {}

if additional_text_features:

    # we know these from creating the dataset
    # moving forward we'd need a better way to dynamically get this information
    encoding_lengths={
        "pos_encoding": 19,
        "dep_encoding": 45
    }
    encoding_cols = ({'pos_encoding': 'pos_encoding_count',
                        'dep_encoding': 'dep_encoding_count'})
    encoding_cols = {k: v for k, v in encoding_cols.items() if k in additional_text_features}
    collate_fn = make_collate_plus(device=device, vocab=review_vocab, 
                                                  encoded_cols=additional_text_features),
                                                  encoding_lengths=encoding_lengths)



train_dataloader = get_dataloader(TRAIN_FILE,  BATCH_SIZE, SHUFFLE,
                                  optional_cols=additional_text_features,
                                  encoded_cols=encoding_cols,
                                  collate=collate_fn)
valid_dataloader = get_dataloader(VALID_FILE,  BATCH_SIZE, SHUFFLE,
                                  optional_cols=additional_text_features,
                                  encoded_cols=encoding_cols,
                                  collate=collate_fn)
test_dataloader = get_dataloader(TEST_FILE,  BATCH_SIZE, SHUFFLE,
                                  optional_cols=additional_text_features,
                                  encoded_cols=encoding_cols,
                                  collate=collate_fn)
# Out:
# get dataloader called
# reading file ./drive/MyDrive/drugproject/3_data/grasser_data_for_lstm/train_grasser_data.csv
# loading line 0
# loading line 10000
# loading line 20000
# loading line 30000
# loading line 40000
# loading line 50000
# loading line 60000
# loading line 70000
# loading line 80000
# loading line 90000
# loading line 100000
# loading line 110000
# loading line 120000
# loading line 130000
# get dataloader called
# reading file ./drive/MyDrive/drugproject/3_data/grasser_data_for_lstm/valid_grasser_data.csv
# loading line 0
# loading line 10000
# loading line 20000
# get dataloader called
# reading file ./drive/MyDrive/drugproject/3_data/grasser_data_for_lstm/test_grasser_data.csv
# loading line 0
# loading line 10000
# loading line 20000
# loading line 30000
# loading line 40000
# loading line 50000

# %% [markdown]
# ### Load Embedding
# (Glove for now)

# %%
if embedding_type == 'glove':
    if device == 'cpu':
        VECTORS_CACHE_DIR = '.vector_cache'
        # Please change above to your cache
    else:
        VECTORS_CACHE_DIR = './.vector_cache'
        # This is the default cache on Colab. Caching may not work
        # as expected on Colab.

    glove = GloVe('6B', cache=VECTORS_CACHE_DIR)
    embedding_vectors = glove.get_vecs_by_tokens(review_vocab.itos)
elif embedding_type == 'twitter':
# Out:
# ./.vector_cache/glove.6B.zip: 862MB [02:45, 5.21MB/s]
# 100%|█████████▉| 399602/400000 [00:35<00:00, 11670.76it/s]

# %% [markdown]
# ## Making the model

# %%
NUM_EPOCHS = 30
INPUT_DIM = len(review_vocab)
EMBEDDING_DIM = 300
HIDDEN_DIM = 300
OUTPUT_DIM = 3
N_LAYERS = 2
BIDIRECTIONAL = True
DROPOUT = 0.5
PADDING_IDX = review_vocab.stoi['<pad>']

model = BasicLSTM(INPUT_DIM, 
            EMBEDDING_DIM, 
            HIDDEN_DIM, 
            OUTPUT_DIM, 
            N_LAYERS, 
            BIDIRECTIONAL, 
            DROPOUT, 
            PADDING_IDX).to(device)

# %% [markdown]
# Print number of parameters because why not

# %%
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'The model has {num_params:,} trainable parameters')

# %% [markdown]
# ## Train

# %% [markdown]
# The trainer and evaluator need an unbatch function that tells the objects how to unpack a batch to directly feed into the model.  This is not redundant with a collate function because it excludes the label.

# %%
if additional_text_features:
    def unpack_batch(data):
        reviews = data['reviews']
        lengths = data['lengths']
        tensors = (data[col] for col in additional_text_features)
        extras = torch.cat(tensors, dim=-1)
        return reviews, lengths, extras    

else:
    def unpack_batch(data):
        """
        data: output of dataloader object
        returns: tuple that can be piped directly into model
        """
        reviews = data['reviews']
        lengths = data['lengths']
        return reviews, lengths

# %%
if weights:
    def get_weights(dataloader, num_labels):
        """
        dataloader: training dataloader object
        num_labels (int): number of labels
        returns tensor of weights that can be the weight parameter in loss functions
        """
        label_dict = {}
        count = 0
        for data in dataloader:
            for label in data['labels'].tolist():
                label_dict[label] = label_dict.get(label, 0) + 1
                count += 1

        weights = [0] * num_labels
        for k, v in label_dict.items():
            weights[k]  = count/v

        return torch.tensor(weights)
    weights = get_weights(train_dataloader, 3)
# Out:
# 100%|█████████▉| 399602/400000 [00:50<00:00, 11670.76it/s]
# here are the weights tensor([4.5955, 8.3299, 1.5098])

# %%
optimizer = optim.Adam(model.parameters())
if weights:
    loss_function = nn.CrossEntropyLoss(weight=weights).to(device)
else:
    loss_function = nn.CrossEntropyLoss().to(device)

evaluator = Evaluator(root_dir=RESULTS_DIR, run_name=RESULT_NAME, 
                      unpack_batch_fn=unpack_batch)
trainer = Trainer(loss_fn=loss_function, optimizer=optimizer, unpack_batch_fn=unpack_batch)
plotter = Plotter(f"{RESULTS_DIR}/{RESULT_NAME}")
context = ModelContext(model=model, trainer=trainer, evaluator=evaluator, 
                       plotter=plotter, train_dataloader=train_dataloader, 
                       valid_dataloader=valid_dataloader, test_dataloader=test_dataloader)

context.run(NUM_EPOCHS, LOG_INTERVAL)
# Out:
# The model has 4,597,803 trainable parameters
# At iteration 100 the loss is 0.860.
# At iteration 200 the loss is 0.793.
# At iteration 300 the loss is 0.557.
# At iteration 400 the loss is 0.699.
# At iteration 500 the loss is 0.653.
# At iteration 600 the loss is 0.628.
# At iteration 700 the loss is 0.620.
# At iteration 800 the loss is 0.425.
# At iteration 900 the loss is 0.551.
# At iteration 1000 the loss is 0.615.
# Epoch: 0, time taken: 159.9s, validation accuracy: 0.779.
# At iteration 100 the loss is 0.528.
# At iteration 200 the loss is 0.437.
# At iteration 300 the loss is 0.547.
# At iteration 400 the loss is 0.578.
# At iteration 500 the loss is 0.552.
# At iteration 600 the loss is 0.590.
# At iteration 700 the loss is 0.428.
# At iteration 800 the loss is 0.543.
# At iteration 900 the loss is 0.529.
# At iteration 1000 the loss is 0.638.
# Epoch: 1, time taken: 160.4s, validation accuracy: 0.812.
# At iteration 100 the loss is 0.341.
# At iteration 200 the loss is 0.483.
# At iteration 300 the loss is 0.485.
# At iteration 400 the loss is 0.435.
# At iteration 500 the loss is 0.574.
# At iteration 600 the loss is 0.586.
# At iteration 700 the loss is 0.476.
# At iteration 800 the loss is 0.450.
# At iteration 900 the loss is 0.350.
# At iteration 1000 the loss is 0.386.
# Epoch: 2, time taken: 160.3s, validation accuracy: 0.822.
# At iteration 100 the loss is 0.488.
# At iteration 200 the loss is 0.387.
# At iteration 300 the loss is 0.442.
# At iteration 400 the loss is 0.407.
# At iteration 500 the loss is 0.422.
# At iteration 600 the loss is 0.460.
# At iteration 700 the loss is 0.430.
# At iteration 800 the loss is 0.379.
# At iteration 900 the loss is 0.494.
# At iteration 1000 the loss is 0.363.
# Epoch: 3, time taken: 159.8s, validation accuracy: 0.821.
# At iteration 100 the loss is 0.341.
# At iteration 200 the loss is 0.342.
# At iteration 300 the loss is 0.361.
# At iteration 400 the loss is 0.377.
# At iteration 500 the loss is 0.366.
# At iteration 600 the loss is 0.459.
# At iteration 700 the loss is 0.371.
# At iteration 800 the loss is 0.388.
# At iteration 900 the loss is 0.500.
# At iteration 1000 the loss is 0.336.
# Epoch: 4, time taken: 159.5s, validation accuracy: 0.835.
# At iteration 100 the loss is 0.240.
# At iteration 200 the loss is 0.429.
# At iteration 300 the loss is 0.378.
# At iteration 400 the loss is 0.372.
# At iteration 500 the loss is 0.328.
# At iteration 600 the loss is 0.368.
# At iteration 700 the loss is 0.318.
# At iteration 800 the loss is 0.296.
# At iteration 900 the loss is 0.405.
# At iteration 1000 the loss is 0.320.
# Epoch: 5, time taken: 159.9s, validation accuracy: 0.841.
# At iteration 100 the loss is 0.390.
# At iteration 200 the loss is 0.259.
# At iteration 300 the loss is 0.304.
# At iteration 400 the loss is 0.350.
# At iteration 500 the loss is 0.335.
# At iteration 600 the loss is 0.319.
# At iteration 700 the loss is 0.334.
# At iteration 800 the loss is 0.260.
# At iteration 900 the loss is 0.380.
# At iteration 1000 the loss is 0.381.
# Epoch: 6, time taken: 159.6s, validation accuracy: 0.842.
# At iteration 100 the loss is 0.258.
# At iteration 200 the loss is 0.286.
# At iteration 300 the loss is 0.326.
# At iteration 400 the loss is 0.248.
# At iteration 500 the loss is 0.351.
# At iteration 600 the loss is 0.363.
# At iteration 700 the loss is 0.309.
# At iteration 800 the loss is 0.320.
# At iteration 900 the loss is 0.374.
# At iteration 1000 the loss is 0.310.
# Epoch: 7, time taken: 159.0s, validation accuracy: 0.848.
# At iteration 100 the loss is 0.357.
# At iteration 200 the loss is 0.246.
# At iteration 300 the loss is 0.306.
# At iteration 400 the loss is 0.260.
# At iteration 500 the loss is 0.330.
# At iteration 600 the loss is 0.274.
# At iteration 700 the loss is 0.331.
# At iteration 800 the loss is 0.259.
# At iteration 900 the loss is 0.297.
# At iteration 1000 the loss is 0.306.
# Epoch: 8, time taken: 159.3s, validation accuracy: 0.851.
# At iteration 100 the loss is 0.230.
# At iteration 200 the loss is 0.301.
# At iteration 300 the loss is 0.311.
# At iteration 400 the loss is 0.237.
# At iteration 500 the loss is 0.275.
# At iteration 600 the loss is 0.293.
# At iteration 700 the loss is 0.139.
# At iteration 800 the loss is 0.228.
# At iteration 900 the loss is 0.298.
# At iteration 1000 the loss is 0.248.
# Epoch: 9, time taken: 159.1s, validation accuracy: 0.855.
# At iteration 100 the loss is 0.305.
# At iteration 200 the loss is 0.265.
# At iteration 300 the loss is 0.219.
# At iteration 400 the loss is 0.176.
# At iteration 500 the loss is 0.258.
# At iteration 600 the loss is 0.267.
# At iteration 700 the loss is 0.242.
# At iteration 800 the loss is 0.206.
# At iteration 900 the loss is 0.248.
# At iteration 1000 the loss is 0.281.
# Epoch: 10, time taken: 159.5s, validation accuracy: 0.862.
# At iteration 100 the loss is 0.241.
# At iteration 200 the loss is 0.201.
# At iteration 300 the loss is 0.128.
# At iteration 400 the loss is 0.183.
# At iteration 500 the loss is 0.298.
# At iteration 600 the loss is 0.317.
# At iteration 700 the loss is 0.217.
# At iteration 800 the loss is 0.311.
# At iteration 900 the loss is 0.196.
# At iteration 1000 the loss is 0.267.
# Epoch: 11, time taken: 159.4s, validation accuracy: 0.863.
# At iteration 100 the loss is 0.214.
# At iteration 200 the loss is 0.309.
# At iteration 300 the loss is 0.343.
# At iteration 400 the loss is 0.191.
# At iteration 500 the loss is 0.175.
# At iteration 600 the loss is 0.153.
# At iteration 700 the loss is 0.158.
# At iteration 800 the loss is 0.185.
# At iteration 900 the loss is 0.255.
# At iteration 1000 the loss is 0.273.
# Epoch: 12, time taken: 160.1s, validation accuracy: 0.868.
# At iteration 100 the loss is 0.254.
# At iteration 200 the loss is 0.239.
# At iteration 300 the loss is 0.243.
# At iteration 400 the loss is 0.230.
# At iteration 500 the loss is 0.187.
# At iteration 600 the loss is 0.238.
# At iteration 700 the loss is 0.222.
# At iteration 800 the loss is 0.179.
# At iteration 900 the loss is 0.233.
# At iteration 1000 the loss is 0.221.
# Epoch: 13, time taken: 159.9s, validation accuracy: 0.875.
# At iteration 100 the loss is 0.138.
# At iteration 200 the loss is 0.077.
# At iteration 300 the loss is 0.235.
# At iteration 400 the loss is 0.371.
# At iteration 500 the loss is 0.291.
# At iteration 600 the loss is 0.255.
# At iteration 700 the loss is 0.244.
# At iteration 800 the loss is 0.184.
# At iteration 900 the loss is 0.196.
# At iteration 1000 the loss is 0.270.
# Epoch: 14, time taken: 159.8s, validation accuracy: 0.878.
# At iteration 100 the loss is 0.145.
# At iteration 200 the loss is 0.218.
# At iteration 300 the loss is 0.108.
# At iteration 400 the loss is 0.178.
# At iteration 500 the loss is 0.202.
# At iteration 600 the loss is 0.167.
# At iteration 700 the loss is 0.164.
# At iteration 800 the loss is 0.271.
# At iteration 900 the loss is 0.201.
# At iteration 1000 the loss is 0.306.
# Epoch: 15, time taken: 160.3s, validation accuracy: 0.879.
# At iteration 100 the loss is 0.220.
# At iteration 200 the loss is 0.168.
# At iteration 300 the loss is 0.110.
# At iteration 400 the loss is 0.142.
# At iteration 500 the loss is 0.128.
# At iteration 600 the loss is 0.175.
# At iteration 700 the loss is 0.123.
# At iteration 800 the loss is 0.159.
# At iteration 900 the loss is 0.092.
# At iteration 1000 the loss is 0.137.
# Epoch: 16, time taken: 159.6s, validation accuracy: 0.883.
# At iteration 100 the loss is 0.207.
# At iteration 200 the loss is 0.096.
# At iteration 300 the loss is 0.102.
# At iteration 400 the loss is 0.119.
# At iteration 500 the loss is 0.178.
# At iteration 600 the loss is 0.180.
# At iteration 700 the loss is 0.166.
# At iteration 800 the loss is 0.140.
# At iteration 900 the loss is 0.172.
# At iteration 1000 the loss is 0.156.
# Epoch: 17, time taken: 160.0s, validation accuracy: 0.884.
# At iteration 100 the loss is 0.152.
# At iteration 200 the loss is 0.183.
# At iteration 300 the loss is 0.100.
# At iteration 400 the loss is 0.116.
# At iteration 500 the loss is 0.129.
# At iteration 600 the loss is 0.193.
# At iteration 700 the loss is 0.136.
# At iteration 800 the loss is 0.129.
# At iteration 900 the loss is 0.185.
# At iteration 1000 the loss is 0.234.
# Epoch: 18, time taken: 160.3s, validation accuracy: 0.885.
# At iteration 100 the loss is 0.063.
# At iteration 200 the loss is 0.167.
# At iteration 300 the loss is 0.148.
# At iteration 400 the loss is 0.368.
# At iteration 500 the loss is 0.226.
# At iteration 600 the loss is 0.136.
# At iteration 700 the loss is 0.132.
# At iteration 800 the loss is 0.158.
# At iteration 900 the loss is 0.247.
# At iteration 1000 the loss is 0.169.
# Epoch: 19, time taken: 160.0s, validation accuracy: 0.884.
# At iteration 100 the loss is 0.158.
# At iteration 200 the loss is 0.153.
# At iteration 300 the loss is 0.253.
# At iteration 400 the loss is 0.143.
# At iteration 500 the loss is 0.205.
# At iteration 600 the loss is 0.219.
# At iteration 700 the loss is 0.127.
# At iteration 800 the loss is 0.153.
# At iteration 900 the loss is 0.088.
# At iteration 1000 the loss is 0.119.
# Epoch: 20, time taken: 159.9s, validation accuracy: 0.887.
# At iteration 100 the loss is 0.201.
# At iteration 200 the loss is 0.321.
# At iteration 300 the loss is 0.116.
# At iteration 400 the loss is 0.146.
# At iteration 500 the loss is 0.166.
# At iteration 600 the loss is 0.113.
# At iteration 700 the loss is 0.159.
# At iteration 800 the loss is 0.138.
# At iteration 900 the loss is 0.237.
# At iteration 1000 the loss is 0.155.
# Epoch: 21, time taken: 160.5s, validation accuracy: 0.889.
# At iteration 100 the loss is 0.136.
# At iteration 200 the loss is 0.116.
# At iteration 300 the loss is 0.123.
# At iteration 400 the loss is 0.136.
# At iteration 500 the loss is 0.195.
# At iteration 600 the loss is 0.149.
# At iteration 700 the loss is 0.082.
# At iteration 800 the loss is 0.097.
# At iteration 900 the loss is 0.204.
# At iteration 1000 the loss is 0.182.
# Epoch: 22, time taken: 160.1s, validation accuracy: 0.888.
# At iteration 100 the loss is 0.044.
# At iteration 200 the loss is 0.090.
# At iteration 300 the loss is 0.125.
# At iteration 400 the loss is 0.062.
# At iteration 500 the loss is 0.144.
# At iteration 600 the loss is 0.125.
# At iteration 700 the loss is 0.145.
# At iteration 800 the loss is 0.135.
# At iteration 900 the loss is 0.121.
# At iteration 1000 the loss is 0.155.
# Epoch: 23, time taken: 160.3s, validation accuracy: 0.894.
# At iteration 100 the loss is 0.172.
# At iteration 200 the loss is 0.123.
# At iteration 300 the loss is 0.223.
# At iteration 400 the loss is 0.121.
# At iteration 500 the loss is 0.148.
# At iteration 600 the loss is 0.096.
# At iteration 700 the loss is 0.150.
# At iteration 800 the loss is 0.124.
# At iteration 900 the loss is 0.146.
# At iteration 1000 the loss is 0.178.
# Epoch: 24, time taken: 160.2s, validation accuracy: 0.894.
# At iteration 100 the loss is 0.122.
# At iteration 200 the loss is 0.095.
# At iteration 300 the loss is 0.102.
# At iteration 400 the loss is 0.127.
# At iteration 500 the loss is 0.228.
# At iteration 600 the loss is 0.149.
# At iteration 700 the loss is 0.225.
# At iteration 800 the loss is 0.224.
# At iteration 900 the loss is 0.071.
# At iteration 1000 the loss is 0.149.
# Epoch: 25, time taken: 160.6s, validation accuracy: 0.888.
# At iteration 100 the loss is 0.118.
# At iteration 200 the loss is 0.099.
# At iteration 300 the loss is 0.100.
# At iteration 400 the loss is 0.103.
# At iteration 500 the loss is 0.137.
# At iteration 600 the loss is 0.166.
# At iteration 700 the loss is 0.122.
# At iteration 800 the loss is 0.141.
# At iteration 900 the loss is 0.073.
# At iteration 1000 the loss is 0.096.
# Epoch: 26, time taken: 161.4s, validation accuracy: 0.894.
# At iteration 100 the loss is 0.151.
# At iteration 200 the loss is 0.133.
# At iteration 300 the loss is 0.133.
# At iteration 400 the loss is 0.141.
# At iteration 500 the loss is 0.272.
# At iteration 600 the loss is 0.138.
# At iteration 700 the loss is 0.163.
# At iteration 800 the loss is 0.104.
# At iteration 900 the loss is 0.165.
# At iteration 1000 the loss is 0.112.
# Epoch: 27, time taken: 160.5s, validation accuracy: 0.896.
# At iteration 100 the loss is 0.141.
# At iteration 200 the loss is 0.077.
# At iteration 300 the loss is 0.126.
# At iteration 400 the loss is 0.138.
# At iteration 500 the loss is 0.037.
# At iteration 600 the loss is 0.171.
# At iteration 700 the loss is 0.125.
# At iteration 800 the loss is 0.167.
# At iteration 900 the loss is 0.061.
# At iteration 1000 the loss is 0.189.
# Epoch: 28, time taken: 160.7s, validation accuracy: 0.894.
# At iteration 100 the loss is 0.168.
# At iteration 200 the loss is 0.174.
# At iteration 300 the loss is 0.098.
# At iteration 400 the loss is 0.115.
# At iteration 500 the loss is 0.141.
# At iteration 600 the loss is 0.163.
# At iteration 700 the loss is 0.165.
# At iteration 800 the loss is 0.096.
# At iteration 900 the loss is 0.085.
# At iteration 1000 the loss is 0.097.
# Epoch: 29, time taken: 160.1s, validation accuracy: 0.895.
# making plots dir... ./drive/MyDrive/drugproject/4_results/basic_lstm_grasser_data_no_weighted_loss_run1/plots
# dict_keys(['predictions', 'labels'])
# about to return
# test inputs {'cohens_kappa': 0.7882609133419888, 'accuracy': 0.8959007551240561}
# min y axis val 0.43924930474253354
# printing df         value  epoch         metric_name
# 0    0.784212      1      train_accuracy
# 1    0.824073      2      train_accuracy
# 2    0.838310      3      train_accuracy
# 3    0.846355      4      train_accuracy
# 4    0.867077      5      train_accuracy
# ..        ...    ...                 ...
# 115  0.775532     26  valid_cohens_kappa
# 116  0.786941     27  valid_cohens_kappa
# 117  0.787135     28  valid_cohens_kappa
# 118  0.786136     29  valid_cohens_kappa
# 119  0.788029     30  valid_cohens_kappa
#
# [120 rows x 3 columns]
