# %% [markdown]
# # This script runs the Grasser logit and is intended to be uploaded to AWS to be adapted there

# %% [markdown]
# ## Set up CUDA

# %%
SEED = 30255 # Specify a seed for reproducability
import random
import numpy as np
import torch
import pandas as pd
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(53113)
torch.backends.cudnn.deterministic = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# Import torch and other packages

# %%
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import Vocab
from torch.utils.data.dataset import random_split
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

from collections import Counter
from csv import reader
import time
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare Dataloader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Different files:
# 1. full original test and train
# 2. concatenate originals, drop dups, split train_test
# 3. get #2 and add scraped and drop dups, then split

# %%
# Replace with local csv paths
import os
RPATH = './drive/MyDrive/drugproject/3_data/duplicate_exploration'
APATH = './drive/MyDrive/UChicago/courses/Spring 2021/NLP - Amitabh/drugproject/3_data/duplicate_exploration'
PATH = RPATH

TRAIN_FILE = os.path.join(PATH, "train_original.csv")
TEST_FILE =  os.path.join(PATH, "test_original.csv")
TRAIN_FILE2 = os.path.join(PATH, "train_original_clean.csv")
TEST_FILE2 =  os.path.join(PATH, "test_original_clean.csv")
TRAIN_FILE3 = os.path.join(PATH, "train_enhanced_clean.csv")
TEST_FILE3 =  os.path.join(PATH, "test_enhanced_clean.csv")


BATCH_SIZE = 64
SHUFFLE = True

# %%
import os
os.path.exists(TRAIN_FILE)
# Out:
# True

# %% [markdown]
# ### Create vocab for BoW

# %%
tokenizer = get_tokenizer('basic_english')
counter_reviews = Counter()

REVIEW_COL_NUM = 2

with open(TRAIN_FILE3, 'r', encoding="utf8") as f:
    csv_reader = reader(f)
    for i, row in enumerate(csv_reader):
        tokens = tokenizer(row[REVIEW_COL_NUM])
        counter_reviews.update(tokens)
        if not i % 10000:
            print(f"{i} examples completed")
# Out:
# 0 examples completed
# 10000 examples completed
# 20000 examples completed
# 30000 examples completed
# 40000 examples completed
# 50000 examples completed
# 60000 examples completed
# 70000 examples completed
# 80000 examples completed
# 90000 examples completed
# 100000 examples completed
# 110000 examples completed
# 120000 examples completed
# 130000 examples completed

# %%
vocab_reviews = Vocab(counter_reviews, min_freq=100)

# %% [markdown]
# #### Make Collate
# Typical collate functions that are passed to dataloaders can only take one argument: batch.  Because we want to give ourselves flexibility to adjust tokenizers, word-embedding classes, and vocab classes, we need to be able to pass additional arguments to our collate functions.  We can get around this by create a collate function using make_collate.  See collate.ipynb for more details.  An example of using make_collate_bow is below.

# %%
SENTIMENT_CATEGORIES = {
    "Negative":0,
    "Neutral":1,
    "Positive":2,
    "Postive": 2
}

def make_collate_bow(vocab, tokenizer, device='cpu'):
    """
    device is torch.device object with argument 'cpu' or 'cuda'
    """

    def collate_bow(batch):
        
        labels = []
        text_tensor = None
        for (l, t) in batch:
            labels.append(SENTIMENT_CATEGORIES[l])

            row = torch.zeros(len(vocab)) # should vocab be a parameter to the function?      
            for token in tokenizer(t):
                index = vocab.stoi[token] 
                row[index] += 1
            if text_tensor is not None: # boolean eval of tensors is ambiguous so I have to be more explicit
                text_tensor = torch.cat([text_tensor, row.unsqueeze(0)], 0)
            else:
                text_tensor = row.unsqueeze(0)
            
        sums = torch.sum(text_tensor, 1)  
        text_tensor = text_tensor / sums.unsqueeze(1)
    
        return torch.tensor(labels).to(device), text_tensor.to(device)        


    return collate_bow

collate_fn = make_collate_bow(vocab_reviews, tokenizer, device='cuda')

# %% [markdown]
# ## Data viz function

# %%
import altair as alt
import pandas as pd

def training_lines(training_accuracies, validation_accuracies, test_accuracy, title=None):
  '''
  Inputs:
  training_accuracies: list of length n of the training accuracies obtained at each epoch
  validation_accuries: list of length n of the trianing accuracies obtained at each epoch
  test_accuracy: integer of the highest test score attained
  '''
  epochs = list(map(lambda accs: accs+1, range((len(training_accuracies)))))
  train_df= pd.DataFrame({"accuracy":training_accuracies, "epoch":epochs})
  train_df["Dataset"] = "Training accuracy"
  valid_df = pd.DataFrame({"accuracy":validation_accuracies, "epoch":epochs})
  valid_df["Dataset"] = "Validation accuracy"
  test = [test_accuracy]*len(epochs)
  test_df =pd.DataFrame({"epoch":epochs, "accuracy":test})
  test_df['Dataset'] = "Optimum Test accuracy"
  #df = pd.concat([train_df, valid_df, test_df])
  df = pd.concat([train_df, valid_df])
  df['epoch']= df['epoch'].apply(lambda ep: int(ep))
  min_y_axis = min(min(training_accuracies),min(validation_accuracies), test_accuracy) - 0.1

  line_chart = alt.Chart(df).mark_line(point=True).encode(
      x=alt.X("epoch:Q", axis=alt.Axis(tickMinStep=1)),
      y=alt.Y("accuracy", scale=alt.Scale(domain=[min_y_axis, 1])),
      color='Dataset'
  )

  test_line = alt.Chart(test_df).mark_line(strokeDash=[7,1]).encode(
      x=alt.X("epoch:Q", axis=alt.Axis(tickMinStep=1)),
      y=alt.Y("accuracy", scale=alt.Scale(domain=[min_y_axis, 1])),
      color='Dataset'
  )

  return (line_chart + test_line).configure_point(size=10).properties(title={'text': (title if title else "")})

# %% [markdown]
# ## Dataloader

# %%
class DrugReviewDataset(Dataset):
    def __init__(self, csv_file, x_colname, target_colname):
        """
        the following are assumed about csv_file:
            - headers are in first row
            - there is a column called 'date'
            - there is a column called 'review' which contains the text data
        """
        self.x = []
        self.target = []
        with open(csv_file, 'r', encoding="utf8") as f:
            data = list(reader(f))

        target_colnum = data[0].index(target_colname)
        x_colnum = data[0].index(x_colname)
        for row in data[1:]:
            self.x.append(row[x_colnum])
            self.target.append(row[target_colnum])

        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        """
        idx can be a list or tensor if integers
        """
        example = (self.target[idx], self.x[idx])
        
        return example

def get_dataloader(data_file, batch_size, shuffle, collate=None, split=None,
                   train_sample=None, valid_sample=None):
    """
    datafile: path to input file (should be a csv)
    batch_size: (int) parameter for DataLoader class
    shuffle: (bool) parameter for DataLoader class
    collage: (fn) parameter for DataLoader class
    split: (bool) specifies if there is to be a train-validation split on data
    """

    ds = DrugReviewDataset(data_file, 'review', 'rating_category')
    # ds.target = target_name
    if split:
      train_dl = DataLoader(ds, batch_size=batch_size, shuffle=False, 
                              collate_fn=collate, sampler=train_sample)  
      valid_dl = DataLoader(ds, batch_size=batch_size, shuffle=False, 
                              collate_fn=collate, sampler=valid_sample)
      return train_dl, valid_dl
    
    dataloader = DataLoader(ds, batch_size=batch_size, shuffle=shuffle, collate_fn=collate)
    
    return dataloader

# %% [markdown]
# Split train and validation

# %%
import numpy as np
import pandas as pd
validation_split = 0.2
dataset_size = len(pd.read_csv(TRAIN_FILE))
indices = list(range(dataset_size))
split = int(np.floor(validation_split*dataset_size))
train_indices, valid_indices = indices[split:], indices[:split]
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(valid_indices)

# %%
train_dataloader, valid_dataloader = get_dataloader(TRAIN_FILE, BATCH_SIZE, SHUFFLE,
                                                    collate_fn, split=True, 
                                                    train_sample=train_sampler,
                                                    valid_sample=valid_sampler)

# %%
test_dataloader = get_dataloader(TEST_FILE, BATCH_SIZE, SHUFFLE, collate_fn)

# %%
loss_function = torch.nn.CrossEntropyLoss()

def train_an_epoch(optimizer, model, dataloader, loss_function=loss_function):
    model.train()
    log_interval = 500

    for idx, (label, text) in enumerate(dataloader):
        model.zero_grad()
        log_probs = model(text)
        loss = loss_function(log_probs, label)
        loss.backward()
        optimizer.step()
        if idx % log_interval == 0 and idx > 0:
            print(f'At iteration {idx} the loss is {loss:.3f}.')


def get_accuracy(model, dataloader):
    model.eval()
    with torch.no_grad():    
        total_acc, total_count = 0, 0
        for idx, (label, word_idxs) in enumerate(dataloader):
            log_probs = model.forward(word_idxs)
            total_acc += (log_probs.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc/total_count

# %% [markdown]
# ## LOGIT

# %%
# Step 3. Create Model Class
class LogisticRegression(torch.nn.Module):
    
    def __init__(self, input_dim, output_dim):
        super(LogisticRegression, self).__init__()
        self.linear = torch.nn.Linear(input_dim, output_dim)

    def forward(self, x):
        outputs = self.linear(x)
        return outputs

# %%
for idx, (lt, tt) in enumerate(train_dataloader):
    print(lt.shape, tt.shape)
    if idx == 4: 
        input_d = tt.shape[1]
        break
# Out:
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])

# %%
# Step 4. Instantiate Model Class
batch_size = 64
n_iters = 3000
EPOCHS = 200
input_dim = input_d 
output_dim = 3 # number of classes to predict 
lr_rate = 0.001

# %%
# Step 5. Instantiate Model and Loss Class
model = LogisticRegression(input_dim, output_dim).to(device)
loss_function = torch.nn.CrossEntropyLoss() # computes softmax and then the cross entropy
# Step 6. Instantiate Optimizer Class
optimizer = torch.optim.Adam(model.parameters(), lr=lr_rate)

# %%
train_accuracies = []
valid_accuracies=[]
test_accuracies=[]
for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train_an_epoch(optimizer, model, train_dataloader, loss_function)
    t_accuracy = get_accuracy(model, train_dataloader)
    train_accuracies.append(t_accuracy)
    print("Train accuracy:", t_accuracy)
    v_accuracy = get_accuracy(model, valid_dataloader)
    valid_accuracies.append(v_accuracy)
    test_accuracy = get_accuracy(model, test_dataloader)
    print("Test set accuracy is:{}".format(test_accuracy))
    test_accuracies.append(test_accuracy)
    time_taken = time.time() - epoch_start_time
    print(f'Epoch: {epoch}, time taken: {time_taken:.1f}s, validation accuracy: {v_accuracy:.3f}.')
# Out:
# At iteration 500 the loss is 0.909.
# At iteration 1000 the loss is 0.838.
# At iteration 1500 the loss is 0.880.
# At iteration 2000 the loss is 0.750.
# Train accuracy: 0.6626342627753065
# Test set accuracy is:0.6593200163672209
# Epoch: 1, time taken: 327.6s, validation accuracy: 0.663.
# At iteration 500 the loss is 0.768.
# At iteration 1000 the loss is 0.800.
# At iteration 1500 the loss is 0.865.
# At iteration 2000 the loss is 0.767.
# Train accuracy: 0.6651838993164804
# Test set accuracy is:0.6613845180969385
# Epoch: 2, time taken: 326.5s, validation accuracy: 0.665.
# At iteration 500 the loss is 0.815.
# At iteration 1000 the loss is 0.821.
# At iteration 1500 the loss is 0.802.
# At iteration 2000 the loss is 0.801.
# Train accuracy: 0.6705931586044421
# Test set accuracy is:0.6667596622400773
# Epoch: 3, time taken: 329.6s, validation accuracy: 0.670.
# At iteration 500 the loss is 0.817.
# At iteration 1000 the loss is 0.843.
# At iteration 1500 the loss is 0.787.
# At iteration 2000 the loss is 0.666.
# Train accuracy: 0.6807219578728747
# Test set accuracy is:0.6780679239668191
# Epoch: 4, time taken: 328.0s, validation accuracy: 0.681.
# At iteration 500 the loss is 0.701.
# At iteration 1000 the loss is 0.646.
# At iteration 1500 the loss is 0.592.
# At iteration 2000 the loss is 0.774.
# Train accuracy: 0.690130039213255
# Test set accuracy is:0.687274485734479
# Epoch: 5, time taken: 324.2s, validation accuracy: 0.689.
# At iteration 500 the loss is 0.655.
# At iteration 1000 the loss is 0.649.
# At iteration 1500 the loss is 0.736.
# At iteration 2000 the loss is 0.731.
# Train accuracy: 0.7020412591639672
# Test set accuracy is:0.6987129412639959
# Epoch: 6, time taken: 327.3s, validation accuracy: 0.700.
# At iteration 500 the loss is 0.604.
# At iteration 1000 the loss is 0.601.
# At iteration 1500 the loss is 0.775.
# At iteration 2000 the loss is 0.775.
# Train accuracy: 0.7109688618856461
# Test set accuracy is:0.7070453446415951
# Epoch: 7, time taken: 322.7s, validation accuracy: 0.709.
# At iteration 500 the loss is 0.738.
# At iteration 1000 the loss is 0.631.
# At iteration 1500 the loss is 0.626.
# At iteration 2000 the loss is 0.594.
# Train accuracy: 0.7139137308389777
# Test set accuracy is:0.7096120224677306
# Epoch: 8, time taken: 324.6s, validation accuracy: 0.712.
# At iteration 500 the loss is 0.763.
# At iteration 1000 the loss is 0.555.
# At iteration 1500 the loss is 0.698.
# At iteration 2000 the loss is 0.726.
# Train accuracy: 0.7230505742494459
# Test set accuracy is:0.7185767957445226
# Epoch: 9, time taken: 323.1s, validation accuracy: 0.720.
# At iteration 500 the loss is 0.746.
# At iteration 1000 the loss is 0.716.
# At iteration 1500 the loss is 0.766.
# At iteration 2000 the loss is 0.834.
# Train accuracy: 0.7297307769804243
# Test set accuracy is:0.7254398690622327
# Epoch: 10, time taken: 322.4s, validation accuracy: 0.727.
# At iteration 500 the loss is 0.734.
# At iteration 1000 the loss is 0.705.
# At iteration 1500 the loss is 0.723.
# At iteration 2000 the loss is 0.561.
# Train accuracy: 0.7324896542103876
# Test set accuracy is:0.7279879477736859
# Epoch: 11, time taken: 324.3s, validation accuracy: 0.729.
# At iteration 500 the loss is 0.589.
# At iteration 1000 the loss is 0.655.
# At iteration 1500 the loss is 0.649.
# At iteration 2000 the loss is 0.598.
# Train accuracy: 0.737108448674034
# Test set accuracy is:0.7321541494624856
# Epoch: 12, time taken: 323.5s, validation accuracy: 0.733.
# At iteration 500 the loss is 0.640.
# At iteration 1000 the loss is 0.649.
# At iteration 1500 the loss is 0.849.
# At iteration 2000 the loss is 0.707.
# Train accuracy: 0.7394178459058572
# Test set accuracy is:0.734832421976714
# Epoch: 13, time taken: 322.8s, validation accuracy: 0.735.
# At iteration 500 the loss is 0.717.
# At iteration 1000 the loss is 0.537.
# At iteration 1500 the loss is 0.638.
# At iteration 2000 the loss is 0.473.
# Train accuracy: 0.7424092127900308
# Test set accuracy is:0.7372689060000744
# Epoch: 14, time taken: 322.8s, validation accuracy: 0.738.
# At iteration 500 the loss is 0.673.
# At iteration 1000 the loss is 0.755.
# At iteration 1500 the loss is 0.647.
# At iteration 2000 the loss is 0.538.
# Train accuracy: 0.7473457431144314
# Test set accuracy is:0.743276420042406
# Epoch: 15, time taken: 322.4s, validation accuracy: 0.743.
# At iteration 500 the loss is 0.613.
# At iteration 1000 the loss is 0.688.
# At iteration 1500 the loss is 0.794.
# At iteration 2000 the loss is 0.575.
# Train accuracy: 0.7465552782901161
# Test set accuracy is:0.7423464643082989
# Epoch: 16, time taken: 322.1s, validation accuracy: 0.742.
# At iteration 500 the loss is 0.670.
# At iteration 1000 the loss is 0.553.
# At iteration 1500 the loss is 0.697.
# At iteration 2000 the loss is 0.696.
# Train accuracy: 0.748856925866799
# Test set accuracy is:0.7443923669233344
# Epoch: 17, time taken: 321.6s, validation accuracy: 0.745.
# At iteration 500 the loss is 0.642.
# At iteration 1000 the loss is 0.487.
# At iteration 1500 the loss is 0.563.
# At iteration 2000 the loss is 0.550.
# Train accuracy: 0.7527472527472527
# Test set accuracy is:0.7476472119927091
# Epoch: 18, time taken: 321.4s, validation accuracy: 0.748.
# At iteration 500 the loss is 0.785.
# At iteration 1000 the loss is 0.519.
# At iteration 1500 the loss is 0.740.
# At iteration 2000 the loss is 0.634.
# Train accuracy: 0.7522745237836916
# Test set accuracy is:0.747107837666927
# Epoch: 19, time taken: 321.0s, validation accuracy: 0.748.
# At iteration 500 the loss is 0.671.
# At iteration 1000 the loss is 0.618.
# At iteration 1500 the loss is 0.588.
# At iteration 2000 the loss is 0.745.
# Train accuracy: 0.7555448782529177
# Test set accuracy is:0.750530074768441
# Epoch: 20, time taken: 320.5s, validation accuracy: 0.751.
# At iteration 500 the loss is 0.644.
# At iteration 1000 the loss is 0.671.
# At iteration 1500 the loss is 0.603.
# At iteration 2000 the loss is 0.454.
# Train accuracy: 0.755529378942637
# Test set accuracy is:0.750269687162891
# Epoch: 21, time taken: 320.3s, validation accuracy: 0.751.
# At iteration 500 the loss is 0.756.
# At iteration 1000 the loss is 0.602.
# At iteration 1500 the loss is 0.595.
# At iteration 2000 the loss is 0.702.
# Train accuracy: 0.7572885506594956
# Test set accuracy is:0.7519436074842838
# Epoch: 22, time taken: 320.7s, validation accuracy: 0.752.
# At iteration 500 the loss is 0.524.
# At iteration 1000 the loss is 0.480.
# At iteration 1500 the loss is 0.670.
# At iteration 2000 the loss is 0.676.
# Train accuracy: 0.7594507044436523
# Test set accuracy is:0.7533199419707622
# Epoch: 23, time taken: 320.4s, validation accuracy: 0.753.
# At iteration 500 the loss is 0.833.
# At iteration 1000 the loss is 0.611.
# At iteration 1500 the loss is 0.622.
# At iteration 2000 the loss is 0.522.
# Train accuracy: 0.762465320293247
# Test set accuracy is:0.7553472454711155
# Epoch: 24, time taken: 320.8s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.562.
# At iteration 1000 the loss is 0.617.
# At iteration 1500 the loss is 0.791.
# At iteration 2000 the loss is 0.584.
# Train accuracy: 0.7607603961623708
# Test set accuracy is:0.7543800915076443
# Epoch: 25, time taken: 320.2s, validation accuracy: 0.755.
# At iteration 500 the loss is 0.543.
# At iteration 1000 the loss is 0.682.
# At iteration 1500 the loss is 0.570.
# At iteration 2000 the loss is 0.551.
# Train accuracy: 0.7630620437390536
# Test set accuracy is:0.7562214038611762
# Epoch: 26, time taken: 320.0s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.529.
# At iteration 1000 the loss is 0.646.
# At iteration 1500 the loss is 0.754.
# At iteration 2000 the loss is 0.619.
# Train accuracy: 0.7656116802802275
# Test set accuracy is:0.7581185135587546
# Epoch: 27, time taken: 320.1s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.621.
# At iteration 1000 the loss is 0.680.
# At iteration 1500 the loss is 0.705.
# At iteration 2000 the loss is 0.565.
# Train accuracy: 0.7648754630418947
# Test set accuracy is:0.7577279321504297
# Epoch: 28, time taken: 320.3s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.626.
# At iteration 1000 the loss is 0.553.
# At iteration 1500 the loss is 0.643.
# At iteration 2000 the loss is 0.548.
# Train accuracy: 0.7667353802755777
# Test set accuracy is:0.7594762489305509
# Epoch: 29, time taken: 319.6s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.536.
# At iteration 1000 the loss is 0.573.
# At iteration 1500 the loss is 0.553.
# At iteration 2000 the loss is 0.505.
# Train accuracy: 0.7668051271718409
# Test set accuracy is:0.7595134471599152
# Epoch: 30, time taken: 319.9s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.580.
# At iteration 1000 the loss is 0.786.
# At iteration 1500 the loss is 0.459.
# At iteration 2000 the loss is 0.467.
# Train accuracy: 0.7674638478587703
# Test set accuracy is:0.760145817059108
# Epoch: 31, time taken: 320.9s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.337.
# At iteration 1000 the loss is 0.617.
# At iteration 1500 the loss is 0.483.
# At iteration 2000 the loss is 0.544.
# Train accuracy: 0.7683318092344891
# Test set accuracy is:0.7611315701372615
# Epoch: 32, time taken: 320.0s, validation accuracy: 0.762.
# At iteration 500 the loss is 0.505.
# At iteration 1000 the loss is 0.573.
# At iteration 1500 the loss is 0.531.
# At iteration 2000 the loss is 0.689.
# Train accuracy: 0.7692385188859096
# Test set accuracy is:0.7620801249860507
# Epoch: 33, time taken: 319.2s, validation accuracy: 0.763.
# At iteration 500 the loss is 0.569.
# At iteration 1000 the loss is 0.518.
# At iteration 1500 the loss is 0.599.
# At iteration 2000 the loss is 0.405.
# Train accuracy: 0.7700832312962074
# Test set accuracy is:0.7630844771788863
# Epoch: 34, time taken: 323.1s, validation accuracy: 0.764.
# At iteration 500 the loss is 0.707.
# At iteration 1000 the loss is 0.533.
# At iteration 1500 the loss is 0.488.
# At iteration 2000 the loss is 0.762.
# Train accuracy: 0.7709589423270664
# Test set accuracy is:0.7640144329129933
# Epoch: 35, time taken: 325.9s, validation accuracy: 0.765.
# At iteration 500 the loss is 0.609.
# At iteration 1000 the loss is 0.634.
# At iteration 1500 the loss is 0.514.
# At iteration 2000 the loss is 0.657.
# Train accuracy: 0.7706954540522947
# Test set accuracy is:0.7639028382249005
# Epoch: 36, time taken: 323.9s, validation accuracy: 0.765.
# At iteration 500 the loss is 0.489.
# At iteration 1000 the loss is 0.552.
# At iteration 1500 the loss is 0.520.
# At iteration 2000 the loss is 0.655.
# Train accuracy: 0.7717726561168028
# Test set accuracy is:0.7649629877617825
# Epoch: 37, time taken: 323.9s, validation accuracy: 0.766.
# At iteration 500 the loss is 0.606.
# At iteration 1000 the loss is 0.638.
# At iteration 1500 the loss is 0.722.
# At iteration 2000 the loss is 0.469.
# Train accuracy: 0.7735628264542228
# Test set accuracy is:0.766339322248261
# Epoch: 38, time taken: 323.5s, validation accuracy: 0.767.
# At iteration 500 the loss is 0.693.
# At iteration 1000 the loss is 0.534.
# At iteration 1500 the loss is 0.614.
# At iteration 2000 the loss is 0.600.
# Train accuracy: 0.7722143864598026
# Test set accuracy is:0.7651861771379682
# Epoch: 39, time taken: 323.6s, validation accuracy: 0.766.
# At iteration 500 the loss is 0.514.
# At iteration 1000 the loss is 0.593.
# At iteration 1500 the loss is 0.609.
# At iteration 2000 the loss is 0.441.
# Train accuracy: 0.7742525457617137
# Test set accuracy is:0.7668043001153145
# Epoch: 40, time taken: 323.2s, validation accuracy: 0.767.
# At iteration 500 the loss is 0.570.
# At iteration 1000 the loss is 0.500.
# At iteration 1500 the loss is 0.529.
# At iteration 2000 the loss is 0.689.
# Train accuracy: 0.7742370464514329
# Test set accuracy is:0.7669158948034074
# Epoch: 41, time taken: 323.4s, validation accuracy: 0.767.
# At iteration 500 the loss is 0.647.
# At iteration 1000 the loss is 0.613.
# At iteration 1500 the loss is 0.404.
# At iteration 2000 the loss is 0.629.
# Train accuracy: 0.7747562733458361
# Test set accuracy is:0.7673622735557788
# Epoch: 42, time taken: 320.5s, validation accuracy: 0.768.
# At iteration 500 the loss is 0.650.
# At iteration 1000 the loss is 0.618.
# At iteration 1500 the loss is 0.632.
# At iteration 2000 the loss is 0.658.
# Train accuracy: 0.775872223686046
# Test set accuracy is:0.7685712160101179
# Epoch: 43, time taken: 319.2s, validation accuracy: 0.769.
# At iteration 500 the loss is 0.682.
# At iteration 1000 the loss is 0.565.
# At iteration 1500 the loss is 0.514.
# At iteration 2000 the loss is 0.527.
# Train accuracy: 0.7756552333421163
# Test set accuracy is:0.7687758062716215
# Epoch: 44, time taken: 319.5s, validation accuracy: 0.769.
# At iteration 500 the loss is 0.698.
# At iteration 1000 the loss is 0.511.
# At iteration 1500 the loss is 0.541.
# At iteration 2000 the loss is 0.549.
# Train accuracy: 0.7756242347215548
# Test set accuracy is:0.7688316036156679
# Epoch: 45, time taken: 319.8s, validation accuracy: 0.769.
# At iteration 500 the loss is 0.757.
# At iteration 1000 the loss is 0.563.
# At iteration 1500 the loss is 0.498.
# At iteration 2000 the loss is 0.669.
# Train accuracy: 0.7765309443729754
# Test set accuracy is:0.7691663876799464
# Epoch: 46, time taken: 319.8s, validation accuracy: 0.769.
# At iteration 500 the loss is 0.543.
# At iteration 1000 the loss is 0.463.
# At iteration 1500 the loss is 0.442.
# At iteration 2000 the loss is 0.731.
# Train accuracy: 0.7767169360963437
# Test set accuracy is:0.7693151805974036
# Epoch: 47, time taken: 319.7s, validation accuracy: 0.769.
# At iteration 500 the loss is 0.531.
# At iteration 1000 the loss is 0.593.
# At iteration 1500 the loss is 0.711.
# At iteration 2000 the loss is 0.576.
# Train accuracy: 0.7781041243664657
# Test set accuracy is:0.7703195327902392
# Epoch: 48, time taken: 320.9s, validation accuracy: 0.770.
# At iteration 500 the loss is 0.480.
# At iteration 1000 the loss is 0.576.
# At iteration 1500 the loss is 0.585.
# At iteration 2000 the loss is 0.598.
# Train accuracy: 0.778669849191711
# Test set accuracy is:0.7709333035747499
# Epoch: 49, time taken: 318.7s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.608.
# At iteration 1000 the loss is 0.477.
# At iteration 1500 the loss is 0.653.
# At iteration 2000 the loss is 0.571.
# Train accuracy: 0.7788248422945179
# Test set accuracy is:0.7710820964922069
# Epoch: 50, time taken: 318.7s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.403.
# At iteration 1000 the loss is 0.524.
# At iteration 1500 the loss is 0.633.
# At iteration 2000 the loss is 0.667.
# Train accuracy: 0.7799097940141664
# Test set accuracy is:0.7713982814418033
# Epoch: 51, time taken: 319.2s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.585.
# At iteration 1000 the loss is 0.561.
# At iteration 1500 the loss is 0.499.
# At iteration 2000 the loss is 0.516.
# Train accuracy: 0.7794835629814473
# Test set accuracy is:0.771472677900532
# Epoch: 52, time taken: 319.0s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.518.
# At iteration 1000 the loss is 0.602.
# At iteration 1500 the loss is 0.530.
# At iteration 2000 the loss is 0.629.
# Train accuracy: 0.7784761078132023
# Test set accuracy is:0.7705799203957892
# Epoch: 53, time taken: 319.1s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.559.
# At iteration 1000 the loss is 0.515.
# At iteration 1500 the loss is 0.630.
# At iteration 2000 the loss is 0.525.
# Train accuracy: 0.7792588229823773
# Test set accuracy is:0.7715284752445783
# Epoch: 54, time taken: 318.8s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.532.
# At iteration 1000 the loss is 0.430.
# At iteration 1500 the loss is 0.464.
# At iteration 2000 the loss is 0.768.
# Train accuracy: 0.7797548009113594
# Test set accuracy is:0.7717888628501284
# Epoch: 55, time taken: 318.7s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.510.
# At iteration 1000 the loss is 0.714.
# At iteration 1500 the loss is 0.386.
# At iteration 2000 the loss is 0.736.
# Train accuracy: 0.779452564360886
# Test set accuracy is:0.7716586690473534
# Epoch: 56, time taken: 318.9s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.595.
# At iteration 1000 the loss is 0.469.
# At iteration 1500 the loss is 0.589.
# At iteration 2000 the loss is 0.585.
# Train accuracy: 0.7808707512515694
# Test set accuracy is:0.7725700256667782
# Epoch: 57, time taken: 319.2s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.701.
# At iteration 1000 the loss is 0.571.
# At iteration 1500 the loss is 0.622.
# At iteration 2000 the loss is 0.614.
# Train accuracy: 0.7823741843487965
# Test set accuracy is:0.7734069858274746
# Epoch: 58, time taken: 318.9s, validation accuracy: 0.776.
# At iteration 500 the loss is 0.434.
# At iteration 1000 the loss is 0.768.
# At iteration 1500 the loss is 0.621.
# At iteration 2000 the loss is 0.446.
# Train accuracy: 0.7812117360777445
# Test set accuracy is:0.7726072238961426
# Epoch: 59, time taken: 319.4s, validation accuracy: 0.775.
# At iteration 500 the loss is 0.531.
# At iteration 1000 the loss is 0.586.
# At iteration 1500 the loss is 0.578.
# At iteration 2000 the loss is 0.750.
# Train accuracy: 0.781490723662797
# Test set accuracy is:0.7729420079604211
# Epoch: 60, time taken: 319.5s, validation accuracy: 0.775.
# At iteration 500 the loss is 0.557.
# At iteration 1000 the loss is 0.534.
# At iteration 1500 the loss is 0.598.
# At iteration 2000 the loss is 0.556.
# Train accuracy: 0.7820874471086037
# Test set accuracy is:0.7733511884834282
# Epoch: 61, time taken: 319.2s, validation accuracy: 0.776.
# At iteration 500 the loss is 0.522.
# At iteration 1000 the loss is 0.591.
# At iteration 1500 the loss is 0.787.
# At iteration 2000 the loss is 0.691.
# Train accuracy: 0.7816457167656039
# Test set accuracy is:0.7728304132723283
# Epoch: 62, time taken: 319.5s, validation accuracy: 0.775.
# At iteration 500 the loss is 0.625.
# At iteration 1000 the loss is 0.566.
# At iteration 1500 the loss is 0.486.
# At iteration 2000 the loss is 0.376.
# Train accuracy: 0.782296687797393
# Test set accuracy is:0.7734255849421567
# Epoch: 63, time taken: 319.3s, validation accuracy: 0.776.
# At iteration 500 the loss is 0.578.
# At iteration 1000 the loss is 0.666.
# At iteration 1500 the loss is 0.615.
# At iteration 2000 the loss is 0.425.
# Train accuracy: 0.7822811884871124
# Test set accuracy is:0.7733883867127924
# Epoch: 64, time taken: 319.4s, validation accuracy: 0.776.
# At iteration 500 the loss is 0.715.
# At iteration 1000 the loss is 0.504.
# At iteration 1500 the loss is 0.520.
# At iteration 2000 the loss is 0.640.
# Train accuracy: 0.7823121871076737
# Test set accuracy is:0.7736859725477068
# Epoch: 65, time taken: 319.7s, validation accuracy: 0.776.
# At iteration 500 the loss is 0.402.
# At iteration 1000 the loss is 0.616.
# At iteration 1500 the loss is 0.643.
# At iteration 2000 the loss is 0.735.
# Train accuracy: 0.7848385746834265
# Test set accuracy is:0.7752668972956888
# Epoch: 66, time taken: 319.2s, validation accuracy: 0.778.
# At iteration 500 the loss is 0.357.
# At iteration 1000 the loss is 0.476.
# At iteration 1500 the loss is 0.665.
# At iteration 2000 the loss is 0.535.
# Train accuracy: 0.7837768719291992
# Test set accuracy is:0.774653126511178
# Epoch: 67, time taken: 319.2s, validation accuracy: 0.778.
# At iteration 500 the loss is 0.525.
# At iteration 1000 the loss is 0.434.
# At iteration 1500 the loss is 0.672.
# At iteration 2000 the loss is 0.556.
# Train accuracy: 0.784063609169392
# Test set accuracy is:0.774913514116728
# Epoch: 68, time taken: 319.1s, validation accuracy: 0.778.
# At iteration 500 the loss is 0.802.
# At iteration 1000 the loss is 0.625.
# At iteration 1500 the loss is 0.564.
# At iteration 2000 the loss is 0.623.
# Train accuracy: 0.7832731443450767
# Test set accuracy is:0.7738905628092103
# Epoch: 69, time taken: 319.6s, validation accuracy: 0.776.
# At iteration 500 the loss is 0.508.
# At iteration 1000 the loss is 0.634.
# At iteration 1500 the loss is 0.532.
# At iteration 2000 the loss is 0.555.
# Train accuracy: 0.7838698677908833
# Test set accuracy is:0.7744113380203103
# Epoch: 70, time taken: 318.9s, validation accuracy: 0.778.
# At iteration 500 the loss is 0.628.
# At iteration 1000 the loss is 0.522.
# At iteration 1500 the loss is 0.602.
# At iteration 2000 the loss is 0.532.
# Train accuracy: 0.7844045939955672
# Test set accuracy is:0.7750251088048209
# Epoch: 71, time taken: 319.0s, validation accuracy: 0.778.
# At iteration 500 the loss is 0.591.
# At iteration 1000 the loss is 0.562.
# At iteration 1500 the loss is 0.628.
# At iteration 2000 the loss is 0.641.
# Train accuracy: 0.7843890946852865
# Test set accuracy is:0.774783320313953
# Epoch: 72, time taken: 317.6s, validation accuracy: 0.778.
# At iteration 500 the loss is 0.519.
# At iteration 1000 the loss is 0.641.
# At iteration 1500 the loss is 0.507.
# At iteration 2000 the loss is 0.500.
# Train accuracy: 0.7845363381329531
# Test set accuracy is:0.7749321132314102
# Epoch: 73, time taken: 318.1s, validation accuracy: 0.778.
# At iteration 500 the loss is 0.756.
# At iteration 1000 the loss is 0.599.
# At iteration 1500 the loss is 0.613.
# At iteration 2000 the loss is 0.647.
# Train accuracy: 0.784892822269409
# Test set accuracy is:0.7748577167726817
# Epoch: 74, time taken: 317.6s, validation accuracy: 0.779.
# At iteration 500 the loss is 0.561.
# At iteration 1000 the loss is 0.451.
# At iteration 1500 the loss is 0.522.
# At iteration 2000 the loss is 0.476.
# Train accuracy: 0.7862877601946714
# Test set accuracy is:0.7764572406353457
# Epoch: 75, time taken: 317.9s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.507.
# At iteration 1000 the loss is 0.580.
# At iteration 1500 the loss is 0.513.
# At iteration 2000 the loss is 0.710.
# Train accuracy: 0.7850245664067949
# Test set accuracy is:0.7750251088048209
# Epoch: 76, time taken: 318.1s, validation accuracy: 0.778.
# At iteration 500 the loss is 0.532.
# At iteration 1000 the loss is 0.459.
# At iteration 1500 the loss is 0.658.
# At iteration 2000 the loss is 0.395.
# Train accuracy: 0.785319053302128
# Test set accuracy is:0.7755272849012387
# Epoch: 77, time taken: 317.8s, validation accuracy: 0.779.
# At iteration 500 the loss is 0.581.
# At iteration 1000 the loss is 0.453.
# At iteration 1500 the loss is 0.564.
# At iteration 2000 the loss is 0.505.
# Train accuracy: 0.7857762829554085
# Test set accuracy is:0.7758992671948816
# Epoch: 78, time taken: 317.7s, validation accuracy: 0.779.
# At iteration 500 the loss is 0.628.
# At iteration 1000 the loss is 0.452.
# At iteration 1500 the loss is 0.514.
# At iteration 2000 the loss is 0.536.
# Train accuracy: 0.7865125001937414
# Test set accuracy is:0.77649443886471
# Epoch: 79, time taken: 317.7s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.545.
# At iteration 1000 the loss is 0.533.
# At iteration 1500 the loss is 0.629.
# At iteration 2000 the loss is 0.513.
# Train accuracy: 0.7865744974348642
# Test set accuracy is:0.7767548264702601
# Epoch: 80, time taken: 317.8s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.663.
# At iteration 1000 the loss is 0.451.
# At iteration 1500 the loss is 0.690.
# At iteration 2000 the loss is 0.515.
# Train accuracy: 0.7865589981245834
# Test set accuracy is:0.7765688353234386
# Epoch: 81, time taken: 317.8s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.416.
# At iteration 1000 the loss is 0.589.
# At iteration 1500 the loss is 0.643.
# At iteration 2000 the loss is 0.492.
# Train accuracy: 0.7863420077806538
# Test set accuracy is:0.7763456459472529
# Epoch: 82, time taken: 317.8s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.581.
# At iteration 1000 the loss is 0.487.
# At iteration 1500 the loss is 0.583.
# At iteration 2000 the loss is 0.508.
# Train accuracy: 0.7876826981199336
# Test set accuracy is:0.7776289848603206
# Epoch: 83, time taken: 317.7s, validation accuracy: 0.781.
# At iteration 500 the loss is 0.536.
# At iteration 1000 the loss is 0.600.
# At iteration 1500 the loss is 0.496.
# At iteration 2000 the loss is 0.473.
# Train accuracy: 0.78670624157225
# Test set accuracy is:0.7765130379793922
# Epoch: 84, time taken: 319.3s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.518.
# At iteration 1000 the loss is 0.490.
# At iteration 1500 the loss is 0.515.
# At iteration 2000 the loss is 0.497.
# Train accuracy: 0.7872022195012321
# Test set accuracy is:0.7769594167317636
# Epoch: 85, time taken: 321.5s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.582.
# At iteration 1000 the loss is 0.538.
# At iteration 1500 the loss is 0.364.
# At iteration 2000 the loss is 0.364.
# Train accuracy: 0.7866674932965483
# Test set accuracy is:0.7766060335528029
# Epoch: 86, time taken: 322.1s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.436.
# At iteration 1000 the loss is 0.490.
# At iteration 1500 the loss is 0.485.
# At iteration 2000 the loss is 0.628.
# Train accuracy: 0.7868302360544955
# Test set accuracy is:0.7768292229289886
# Epoch: 87, time taken: 322.7s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.550.
# At iteration 1000 the loss is 0.538.
# At iteration 1500 the loss is 0.660.
# At iteration 2000 the loss is 0.639.
# Train accuracy: 0.7880779305320913
# Test set accuracy is:0.7773871963694529
# Epoch: 88, time taken: 322.2s, validation accuracy: 0.781.
# At iteration 500 the loss is 0.672.
# At iteration 1000 the loss is 0.514.
# At iteration 1500 the loss is 0.531.
# At iteration 2000 the loss is 0.529.
# Train accuracy: 0.7870704753638463
# Test set accuracy is:0.7766432317821672
# Epoch: 89, time taken: 322.0s, validation accuracy: 0.780.
# At iteration 500 the loss is 0.515.
# At iteration 1000 the loss is 0.497.
# At iteration 1500 the loss is 0.513.
# At iteration 2000 the loss is 0.571.
# Train accuracy: 0.7883414188068631
# Test set accuracy is:0.7778335751218242
# Epoch: 90, time taken: 322.0s, validation accuracy: 0.781.
# At iteration 500 the loss is 0.737.
# At iteration 1000 the loss is 0.451.
# At iteration 1500 the loss is 0.516.
# At iteration 2000 the loss is 0.396.
# Train accuracy: 0.7887831491498628
# Test set accuracy is:0.7784845441356991
# Epoch: 91, time taken: 322.1s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.328.
# At iteration 1000 the loss is 0.642.
# At iteration 1500 the loss is 0.619.
# At iteration 2000 the loss is 0.523.
# Train accuracy: 0.7885971574264945
# Test set accuracy is:0.7783915485622884
# Epoch: 92, time taken: 322.6s, validation accuracy: 0.781.
# At iteration 500 the loss is 0.574.
# At iteration 1000 the loss is 0.439.
# At iteration 1500 the loss is 0.564.
# At iteration 2000 the loss is 0.638.
# Train accuracy: 0.7877369457059161
# Test set accuracy is:0.7773127999107242
# Epoch: 93, time taken: 323.0s, validation accuracy: 0.781.
# At iteration 500 the loss is 0.475.
# At iteration 1000 the loss is 0.754.
# At iteration 1500 the loss is 0.605.
# At iteration 2000 the loss is 0.547.
# Train accuracy: 0.7887986484601435
# Test set accuracy is:0.7785775397091098
# Epoch: 94, time taken: 322.6s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.569.
# At iteration 1000 the loss is 0.531.
# At iteration 1500 the loss is 0.691.
# At iteration 2000 the loss is 0.510.
# Train accuracy: 0.7895348656984764
# Test set accuracy is:0.7786705352825205
# Epoch: 95, time taken: 322.4s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.476.
# At iteration 1000 the loss is 0.610.
# At iteration 1500 the loss is 0.507.
# At iteration 2000 the loss is 0.595.
# Train accuracy: 0.7893411243199677
# Test set accuracy is:0.778856526429342
# Epoch: 96, time taken: 322.4s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.477.
# At iteration 1000 the loss is 0.518.
# At iteration 1500 the loss is 0.632.
# At iteration 2000 the loss is 0.532.
# Train accuracy: 0.789527116043336
# Test set accuracy is:0.7790797158055277
# Epoch: 97, time taken: 323.7s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.489.
# At iteration 1000 the loss is 0.480.
# At iteration 1500 the loss is 0.468.
# At iteration 2000 the loss is 0.542.
# Train accuracy: 0.7886281560470559
# Test set accuracy is:0.7781869583007849
# Epoch: 98, time taken: 322.5s, validation accuracy: 0.781.
# At iteration 500 the loss is 0.642.
# At iteration 1000 the loss is 0.492.
# At iteration 1500 the loss is 0.611.
# At iteration 2000 the loss is 0.700.
# Train accuracy: 0.7893333746648274
# Test set accuracy is:0.7785589405944277
# Epoch: 99, time taken: 322.6s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.515.
# At iteration 1000 the loss is 0.458.
# At iteration 1500 the loss is 0.463.
# At iteration 2000 the loss is 0.639.
# Train accuracy: 0.7889381422526698
# Test set accuracy is:0.7782427556448313
# Epoch: 100, time taken: 322.7s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.630.
# At iteration 1000 the loss is 0.465.
# At iteration 1500 the loss is 0.559.
# At iteration 2000 the loss is 0.423.
# Train accuracy: 0.7897286070769851
# Test set accuracy is:0.7793029051817133
# Epoch: 101, time taken: 322.8s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.472.
# At iteration 1000 the loss is 0.481.
# At iteration 1500 the loss is 0.588.
# At iteration 2000 the loss is 0.476.
# Train accuracy: 0.7897673553526868
# Test set accuracy is:0.7789309228880705
# Epoch: 102, time taken: 322.4s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.597.
# At iteration 1000 the loss is 0.624.
# At iteration 1500 the loss is 0.542.
# At iteration 2000 the loss is 0.543.
# Train accuracy: 0.7894496194919326
# Test set accuracy is:0.7785775397091098
# Epoch: 103, time taken: 321.6s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.467.
# At iteration 1000 the loss is 0.269.
# At iteration 1500 the loss is 0.492.
# At iteration 2000 the loss is 0.684.
# Train accuracy: 0.7903795781087741
# Test set accuracy is:0.779526094557899
# Epoch: 104, time taken: 321.5s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.631.
# At iteration 1000 the loss is 0.554.
# At iteration 1500 the loss is 0.641.
# At iteration 2000 the loss is 0.495.
# Train accuracy: 0.7906198174181249
# Test set accuracy is:0.7793959007551241
# Epoch: 105, time taken: 321.9s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.477.
# At iteration 1000 the loss is 0.590.
# At iteration 1500 the loss is 0.588.
# At iteration 2000 the loss is 0.597.
# Train accuracy: 0.7900773415583007
# Test set accuracy is:0.7790239184614812
# Epoch: 106, time taken: 321.6s, validation accuracy: 0.782.
# At iteration 500 the loss is 0.499.
# At iteration 1000 the loss is 0.476.
# At iteration 1500 the loss is 0.545.
# At iteration 2000 the loss is 0.558.
# Train accuracy: 0.7905888187975635
# Test set accuracy is:0.7792285087229848
# Epoch: 107, time taken: 321.6s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.553.
# At iteration 1000 the loss is 0.646.
# At iteration 1500 the loss is 0.397.
# At iteration 2000 the loss is 0.518.
# Train accuracy: 0.7901935863854058
# Test set accuracy is:0.7789867202321169
# Epoch: 108, time taken: 321.9s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.399.
# At iteration 1000 the loss is 0.519.
# At iteration 1500 the loss is 0.554.
# At iteration 2000 the loss is 0.444.
# Train accuracy: 0.7908988050031773
# Test set accuracy is:0.7798422795074954
# Epoch: 109, time taken: 322.9s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.524.
# At iteration 1000 the loss is 0.472.
# At iteration 1500 the loss is 0.645.
# At iteration 2000 the loss is 0.566.
# Train accuracy: 0.7910460484508439
# Test set accuracy is:0.7799910724249526
# Epoch: 110, time taken: 320.8s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.435.
# At iteration 1000 the loss is 0.564.
# At iteration 1500 the loss is 0.501.
# At iteration 2000 the loss is 0.541.
# Train accuracy: 0.7912165408639316
# Test set accuracy is:0.779916675966224
# Epoch: 111, time taken: 320.5s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.673.
# At iteration 1000 the loss is 0.509.
# At iteration 1500 the loss is 0.613.
# At iteration 2000 the loss is 0.605.
# Train accuracy: 0.791472279483563
# Test set accuracy is:0.7797492839340847
# Epoch: 112, time taken: 320.4s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.450.
# At iteration 1000 the loss is 0.489.
# At iteration 1500 the loss is 0.455.
# At iteration 2000 the loss is 0.603.
# Train accuracy: 0.7911622932779492
# Test set accuracy is:0.7797120857047205
# Epoch: 113, time taken: 320.7s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.549.
# At iteration 1000 the loss is 0.666.
# At iteration 1500 the loss is 0.544.
# At iteration 2000 the loss is 0.590.
# Train accuracy: 0.791697019482633
# Test set accuracy is:0.779916675966224
# Epoch: 114, time taken: 320.7s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.627.
# At iteration 1000 the loss is 0.513.
# At iteration 1500 the loss is 0.575.
# At iteration 2000 the loss is 0.497.
# Train accuracy: 0.791317286380756
# Test set accuracy is:0.7796376892459919
# Epoch: 115, time taken: 322.9s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.480.
# At iteration 1000 the loss is 0.480.
# At iteration 1500 the loss is 0.551.
# At iteration 2000 the loss is 0.410.
# Train accuracy: 0.7916892698274927
# Test set accuracy is:0.779786482163449
# Epoch: 116, time taken: 321.9s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.493.
# At iteration 1000 the loss is 0.616.
# At iteration 1500 the loss is 0.604.
# At iteration 2000 the loss is 0.495.
# Train accuracy: 0.7919450084471241
# Test set accuracy is:0.7799352750809061
# Epoch: 117, time taken: 323.8s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.498.
# At iteration 1000 the loss is 0.596.
# At iteration 1500 the loss is 0.410.
# At iteration 2000 the loss is 0.603.
# Train accuracy: 0.7910150498302826
# Test set accuracy is:0.7795818919019455
# Epoch: 118, time taken: 322.9s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.680.
# At iteration 1000 the loss is 0.408.
# At iteration 1500 the loss is 0.514.
# At iteration 2000 the loss is 0.534.
# Train accuracy: 0.7919992560331065
# Test set accuracy is:0.780046869768999
# Epoch: 119, time taken: 328.3s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.611.
# At iteration 1000 the loss is 0.366.
# At iteration 1500 the loss is 0.514.
# At iteration 2000 the loss is 0.614.
# Train accuracy: 0.7920302546536679
# Test set accuracy is:0.7801026671130454
# Epoch: 120, time taken: 331.6s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.420.
# At iteration 1000 the loss is 0.446.
# At iteration 1500 the loss is 0.599.
# At iteration 2000 the loss is 0.546.
# Train accuracy: 0.7916892698274927
# Test set accuracy is:0.7800654688836811
# Epoch: 121, time taken: 330.7s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.683.
# At iteration 1000 the loss is 0.458.
# At iteration 1500 the loss is 0.563.
# At iteration 2000 the loss is 0.573.
# Train accuracy: 0.7925804801686325
# Test set accuracy is:0.7804560502920062
# Epoch: 122, time taken: 330.9s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.688.
# At iteration 1000 the loss is 0.527.
# At iteration 1500 the loss is 0.560.
# At iteration 2000 the loss is 0.521.
# Train accuracy: 0.7923789891349835
# Test set accuracy is:0.7805490458654168
# Epoch: 123, time taken: 333.6s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.579.
# At iteration 1000 the loss is 0.416.
# At iteration 1500 the loss is 0.442.
# At iteration 2000 the loss is 0.512.
# Train accuracy: 0.7924254870658256
# Test set accuracy is:0.7803258564892311
# Epoch: 124, time taken: 328.7s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.496.
# At iteration 1000 the loss is 0.608.
# At iteration 1500 the loss is 0.650.
# At iteration 2000 the loss is 0.592.
# Train accuracy: 0.7928052201677025
# Test set accuracy is:0.7804002529479597
# Epoch: 125, time taken: 333.6s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.633.
# At iteration 1000 the loss is 0.398.
# At iteration 1500 the loss is 0.538.
# At iteration 2000 the loss is 0.566.
# Train accuracy: 0.792681225685457
# Test set accuracy is:0.7801956626864561
# Epoch: 126, time taken: 333.3s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.437.
# At iteration 1000 the loss is 0.583.
# At iteration 1500 the loss is 0.634.
# At iteration 2000 the loss is 0.529.
# Train accuracy: 0.7923867387901239
# Test set accuracy is:0.7802886582598668
# Epoch: 127, time taken: 331.0s, validation accuracy: 0.783.
# At iteration 500 the loss is 0.483.
# At iteration 1000 the loss is 0.477.
# At iteration 1500 the loss is 0.652.
# At iteration 2000 the loss is 0.535.
# Train accuracy: 0.7928439684434043
# Test set accuracy is:0.780437451177324
# Epoch: 128, time taken: 333.5s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.391.
# At iteration 1000 the loss is 0.565.
# At iteration 1500 the loss is 0.484.
# At iteration 2000 the loss is 0.487.
# Train accuracy: 0.7925727305134922
# Test set accuracy is:0.7804188520626418
# Epoch: 129, time taken: 328.8s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.582.
# At iteration 1000 the loss is 0.460.
# At iteration 1500 the loss is 0.644.
# At iteration 2000 the loss is 0.642.
# Train accuracy: 0.7927509725817201
# Test set accuracy is:0.7806234423241454
# Epoch: 130, time taken: 332.2s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.617.
# At iteration 1000 the loss is 0.381.
# At iteration 1500 the loss is 0.624.
# At iteration 2000 the loss is 0.533.
# Train accuracy: 0.7924642353415273
# Test set accuracy is:0.7803816538332775
# Epoch: 131, time taken: 329.1s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.546.
# At iteration 1000 the loss is 0.503.
# At iteration 1500 the loss is 0.494.
# At iteration 2000 the loss is 0.519.
# Train accuracy: 0.7929447139602288
# Test set accuracy is:0.7807164378975561
# Epoch: 132, time taken: 328.5s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.364.
# At iteration 1000 the loss is 0.454.
# At iteration 1500 the loss is 0.740.
# At iteration 2000 the loss is 0.658.
# Train accuracy: 0.792929214649948
# Test set accuracy is:0.7806606405535097
# Epoch: 133, time taken: 329.3s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.554.
# At iteration 1000 the loss is 0.692.
# At iteration 1500 the loss is 0.473.
# At iteration 2000 the loss is 0.594.
# Train accuracy: 0.7933554456826671
# Test set accuracy is:0.7809210281590596
# Epoch: 134, time taken: 328.7s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.479.
# At iteration 1000 the loss is 0.731.
# At iteration 1500 the loss is 0.639.
# At iteration 2000 the loss is 0.422.
# Train accuracy: 0.7931849532695795
# Test set accuracy is:0.7809024290443775
# Epoch: 135, time taken: 334.3s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.420.
# At iteration 1000 the loss is 0.529.
# At iteration 1500 the loss is 0.439.
# At iteration 2000 the loss is 0.352.
# Train accuracy: 0.7929757125807901
# Test set accuracy is:0.7806606405535097
# Epoch: 136, time taken: 334.8s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.526.
# At iteration 1000 the loss is 0.643.
# At iteration 1500 the loss is 0.523.
# At iteration 2000 the loss is 0.589.
# Train accuracy: 0.7937971760256669
# Test set accuracy is:0.7807536361269204
# Epoch: 137, time taken: 328.3s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.427.
# At iteration 1000 the loss is 0.523.
# At iteration 1500 the loss is 0.531.
# At iteration 2000 the loss is 0.442.
# Train accuracy: 0.7931694539592988
# Test set accuracy is:0.7807350370122382
# Epoch: 138, time taken: 324.1s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.633.
# At iteration 1000 the loss is 0.508.
# At iteration 1500 the loss is 0.625.
# At iteration 2000 the loss is 0.664.
# Train accuracy: 0.7936266836125793
# Test set accuracy is:0.7807350370122382
# Epoch: 139, time taken: 327.2s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.533.
# At iteration 1000 the loss is 0.588.
# At iteration 1500 the loss is 0.454.
# At iteration 2000 the loss is 0.465.
# Train accuracy: 0.7937274291294037
# Test set accuracy is:0.7811814157646096
# Epoch: 140, time taken: 328.0s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.557.
# At iteration 1000 the loss is 0.557.
# At iteration 1500 the loss is 0.583.
# At iteration 2000 the loss is 0.400.
# Train accuracy: 0.7939211705079124
# Test set accuracy is:0.7808466317003311
# Epoch: 141, time taken: 329.7s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.480.
# At iteration 1000 the loss is 0.432.
# At iteration 1500 the loss is 0.569.
# At iteration 2000 the loss is 0.439.
# Train accuracy: 0.7941304111967018
# Test set accuracy is:0.7810326228471525
# Epoch: 142, time taken: 328.1s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.554.
# At iteration 1000 the loss is 0.614.
# At iteration 1500 the loss is 0.643.
# At iteration 2000 the loss is 0.377.
# Train accuracy: 0.7937351787845441
# Test set accuracy is:0.7809024290443775
# Epoch: 143, time taken: 327.8s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.509.
# At iteration 1000 the loss is 0.545.
# At iteration 1500 the loss is 0.474.
# At iteration 2000 the loss is 0.642.
# Train accuracy: 0.7942156574032455
# Test set accuracy is:0.7806048432094632
# Epoch: 144, time taken: 327.7s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.596.
# At iteration 1000 the loss is 0.537.
# At iteration 1500 the loss is 1.005.
# At iteration 2000 the loss is 0.599.
# Train accuracy: 0.7945256436088594
# Test set accuracy is:0.7809954246177881
# Epoch: 145, time taken: 327.8s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.561.
# At iteration 1000 the loss is 0.444.
# At iteration 1500 the loss is 0.488.
# At iteration 2000 the loss is 0.484.
# Train accuracy: 0.7941691594724035
# Test set accuracy is:0.7809396272737418
# Epoch: 146, time taken: 328.8s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.671.
# At iteration 1000 the loss is 0.691.
# At iteration 1500 the loss is 0.523.
# At iteration 2000 the loss is 0.627.
# Train accuracy: 0.7943474015406314
# Test set accuracy is:0.7807722352416026
# Epoch: 147, time taken: 328.5s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.437.
# At iteration 1000 the loss is 0.494.
# At iteration 1500 the loss is 0.471.
# At iteration 2000 the loss is 0.444.
# Train accuracy: 0.7941769091275438
# Test set accuracy is:0.7806048432094632
# Epoch: 148, time taken: 329.3s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.451.
# At iteration 1000 the loss is 0.588.
# At iteration 1500 the loss is 0.383.
# At iteration 2000 the loss is 0.508.
# Train accuracy: 0.7942311567135263
# Test set accuracy is:0.7810326228471525
# Epoch: 149, time taken: 330.6s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.648.
# At iteration 1000 the loss is 0.547.
# At iteration 1500 the loss is 0.500.
# At iteration 2000 the loss is 0.420.
# Train accuracy: 0.7945876408499821
# Test set accuracy is:0.7807722352416026
# Epoch: 150, time taken: 329.5s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.737.
# At iteration 1000 the loss is 0.553.
# At iteration 1500 the loss is 0.539.
# At iteration 2000 the loss is 0.387.
# Train accuracy: 0.7944248980920349
# Test set accuracy is:0.7807164378975561
# Epoch: 151, time taken: 330.6s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.341.
# At iteration 1000 the loss is 0.527.
# At iteration 1500 the loss is 0.424.
# At iteration 2000 the loss is 0.443.
# Train accuracy: 0.7945256436088594
# Test set accuracy is:0.7808838299296953
# Epoch: 152, time taken: 334.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.406.
# At iteration 1000 the loss is 0.624.
# At iteration 1500 the loss is 0.692.
# At iteration 2000 the loss is 0.621.
# Train accuracy: 0.794269904989228
# Test set accuracy is:0.7809210281590596
# Epoch: 153, time taken: 329.2s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.685.
# At iteration 1000 the loss is 0.502.
# At iteration 1500 the loss is 0.552.
# At iteration 2000 the loss is 0.684.
# Train accuracy: 0.7947736325733505
# Test set accuracy is:0.7807722352416026
# Epoch: 154, time taken: 328.2s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.475.
# At iteration 1000 the loss is 0.436.
# At iteration 1500 the loss is 0.424.
# At iteration 2000 the loss is 0.463.
# Train accuracy: 0.7952153629163502
# Test set accuracy is:0.7809210281590596
# Epoch: 155, time taken: 327.9s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.493.
# At iteration 1000 the loss is 0.585.
# At iteration 1500 the loss is 0.473.
# At iteration 2000 the loss is 0.574.
# Train accuracy: 0.794920876021017
# Test set accuracy is:0.7808652308150132
# Epoch: 156, time taken: 328.2s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.567.
# At iteration 1000 the loss is 0.472.
# At iteration 1500 the loss is 0.565.
# At iteration 2000 the loss is 0.568.
# Train accuracy: 0.7949983725724206
# Test set accuracy is:0.7811628166499275
# Epoch: 157, time taken: 328.0s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.496.
# At iteration 1000 the loss is 0.482.
# At iteration 1500 the loss is 0.534.
# At iteration 2000 the loss is 0.496.
# Train accuracy: 0.794874378090175
# Test set accuracy is:0.7810512219618346
# Epoch: 158, time taken: 327.9s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.546.
# At iteration 1000 the loss is 0.614.
# At iteration 1500 the loss is 0.500.
# At iteration 2000 the loss is 0.415.
# Train accuracy: 0.7949441249864381
# Test set accuracy is:0.7809582263884239
# Epoch: 159, time taken: 328.1s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.527.
# At iteration 1000 the loss is 0.455.
# At iteration 1500 the loss is 0.650.
# At iteration 2000 the loss is 0.537.
# Train accuracy: 0.79565709325935
# Test set accuracy is:0.7813302086820667
# Epoch: 160, time taken: 329.2s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.447.
# At iteration 1000 the loss is 0.287.
# At iteration 1500 the loss is 0.573.
# At iteration 2000 the loss is 0.409.
# Train accuracy: 0.7955485980873851
# Test set accuracy is:0.7813302086820667
# Epoch: 161, time taken: 327.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.510.
# At iteration 1000 the loss is 0.515.
# At iteration 1500 the loss is 0.574.
# At iteration 2000 the loss is 0.477.
# Train accuracy: 0.7959283311892621
# Test set accuracy is:0.7814790015995239
# Epoch: 162, time taken: 321.2s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.474.
# At iteration 1000 the loss is 0.556.
# At iteration 1500 the loss is 0.581.
# At iteration 2000 the loss is 0.629.
# Train accuracy: 0.7956493436042096
# Test set accuracy is:0.7811256184205632
# Epoch: 163, time taken: 320.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.570.
# At iteration 1000 the loss is 0.463.
# At iteration 1500 the loss is 0.670.
# At iteration 2000 the loss is 0.655.
# Train accuracy: 0.7958895829135604
# Test set accuracy is:0.7813860060261132
# Epoch: 164, time taken: 320.2s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.497.
# At iteration 1000 the loss is 0.522.
# At iteration 1500 the loss is 0.568.
# At iteration 2000 the loss is 0.460.
# Train accuracy: 0.795525349121964
# Test set accuracy is:0.7813116095673845
# Epoch: 165, time taken: 320.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.366.
# At iteration 1000 the loss is 0.610.
# At iteration 1500 the loss is 0.544.
# At iteration 2000 the loss is 0.433.
# Train accuracy: 0.7958585842929989
# Test set accuracy is:0.7811442175352453
# Epoch: 166, time taken: 320.0s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.385.
# At iteration 1000 the loss is 0.515.
# At iteration 1500 the loss is 0.611.
# At iteration 2000 the loss is 0.619.
# Train accuracy: 0.7962925649808583
# Test set accuracy is:0.781237213108656
# Epoch: 167, time taken: 320.3s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.478.
# At iteration 1000 the loss is 0.466.
# At iteration 1500 the loss is 0.539.
# At iteration 2000 the loss is 0.465.
# Train accuracy: 0.7959748291201042
# Test set accuracy is:0.7812558122233382
# Epoch: 168, time taken: 320.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.422.
# At iteration 1000 the loss is 0.569.
# At iteration 1500 the loss is 0.451.
# At iteration 2000 the loss is 0.589.
# Train accuracy: 0.7961840698088936
# Test set accuracy is:0.7810140237324703
# Epoch: 169, time taken: 320.3s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.478.
# At iteration 1000 the loss is 0.602.
# At iteration 1500 the loss is 0.505.
# At iteration 2000 the loss is 0.641.
# Train accuracy: 0.7959670794649638
# Test set accuracy is:0.781237213108656
# Epoch: 170, time taken: 320.1s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.562.
# At iteration 1000 the loss is 0.712.
# At iteration 1500 the loss is 0.504.
# At iteration 2000 the loss is 0.463.
# Train accuracy: 0.7966722980827353
# Test set accuracy is:0.7817207900903917
# Epoch: 171, time taken: 320.2s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.494.
# At iteration 1000 the loss is 0.364.
# At iteration 1500 the loss is 0.544.
# At iteration 2000 the loss is 0.611.
# Train accuracy: 0.7960910739472093
# Test set accuracy is:0.7813116095673845
# Epoch: 172, time taken: 322.0s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.699.
# At iteration 1000 the loss is 0.545.
# At iteration 1500 the loss is 0.476.
# At iteration 2000 the loss is 0.654.
# Train accuracy: 0.7961608208434725
# Test set accuracy is:0.7812930104527025
# Epoch: 173, time taken: 320.9s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.557.
# At iteration 1000 the loss is 0.556.
# At iteration 1500 the loss is 0.411.
# At iteration 2000 the loss is 0.581.
# Train accuracy: 0.7960988236023497
# Test set accuracy is:0.7814790015995239
# Epoch: 174, time taken: 324.1s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.482.
# At iteration 1000 the loss is 0.524.
# At iteration 1500 the loss is 0.507.
# At iteration 2000 the loss is 0.507.
# Train accuracy: 0.7960445760163672
# Test set accuracy is:0.7814232042554774
# Epoch: 175, time taken: 326.1s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.433.
# At iteration 1000 the loss is 0.546.
# At iteration 1500 the loss is 0.431.
# At iteration 2000 the loss is 0.506.
# Train accuracy: 0.7966722980827353
# Test set accuracy is:0.781757988319756
# Epoch: 176, time taken: 323.5s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.524.
# At iteration 1000 the loss is 0.384.
# At iteration 1500 the loss is 0.384.
# At iteration 2000 the loss is 0.617.
# Train accuracy: 0.7968737891163843
# Test set accuracy is:0.7816835918610274
# Epoch: 177, time taken: 319.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.503.
# At iteration 1000 the loss is 0.493.
# At iteration 1500 the loss is 0.481.
# At iteration 2000 the loss is 0.726.
# Train accuracy: 0.7966258001518932
# Test set accuracy is:0.7816091954022989
# Epoch: 178, time taken: 319.0s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.570.
# At iteration 1000 the loss is 0.392.
# At iteration 1500 the loss is 0.444.
# At iteration 2000 the loss is 0.620.
# Train accuracy: 0.7971527767014368
# Test set accuracy is:0.7817021909757096
# Epoch: 179, time taken: 319.9s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.446.
# At iteration 1000 the loss is 0.563.
# At iteration 1500 the loss is 0.304.
# At iteration 2000 the loss is 0.551.
# Train accuracy: 0.7960290767060866
# Test set accuracy is:0.7813488077967489
# Epoch: 180, time taken: 319.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.604.
# At iteration 1000 the loss is 0.488.
# At iteration 1500 the loss is 0.482.
# At iteration 2000 the loss is 0.556.
# Train accuracy: 0.7970287822191913
# Test set accuracy is:0.7815347989435703
# Epoch: 181, time taken: 321.2s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.648.
# At iteration 1000 the loss is 0.420.
# At iteration 1500 the loss is 0.342.
# At iteration 2000 the loss is 0.638.
# Train accuracy: 0.7970132829089106
# Test set accuracy is:0.7814418033701596
# Epoch: 182, time taken: 319.6s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.607.
# At iteration 1000 the loss is 0.518.
# At iteration 1500 the loss is 0.404.
# At iteration 2000 the loss is 0.375.
# Train accuracy: 0.7968970380818053
# Test set accuracy is:0.7816835918610274
# Epoch: 183, time taken: 322.6s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.537.
# At iteration 1000 the loss is 0.368.
# At iteration 1500 the loss is 0.598.
# At iteration 2000 the loss is 0.507.
# Train accuracy: 0.7970597808397526
# Test set accuracy is:0.7814046051407953
# Epoch: 184, time taken: 322.1s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.564.
# At iteration 1000 the loss is 0.507.
# At iteration 1500 the loss is 0.525.
# At iteration 2000 the loss is 0.688.
# Train accuracy: 0.7968505401509632
# Test set accuracy is:0.7815719971729346
# Epoch: 185, time taken: 325.7s, validation accuracy: 0.784.
# At iteration 500 the loss is 0.594.
# At iteration 1000 the loss is 0.532.
# At iteration 1500 the loss is 0.635.
# At iteration 2000 the loss is 0.562.
# Train accuracy: 0.7972147739425596
# Test set accuracy is:0.7818695830078488
# Epoch: 186, time taken: 327.1s, validation accuracy: 0.786.
# At iteration 500 the loss is 0.486.
# At iteration 1000 the loss is 0.460.
# At iteration 1500 the loss is 0.677.
# At iteration 2000 the loss is 0.398.
# Train accuracy: 0.7970985291154543
# Test set accuracy is:0.7817393892050738
# Epoch: 187, time taken: 323.2s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.456.
# At iteration 1000 the loss is 0.581.
# At iteration 1500 the loss is 0.486.
# At iteration 2000 the loss is 0.461.
# Train accuracy: 0.7972070242874192
# Test set accuracy is:0.781627794516981
# Epoch: 188, time taken: 318.7s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.547.
# At iteration 1000 the loss is 0.514.
# At iteration 1500 the loss is 0.554.
# At iteration 2000 the loss is 0.563.
# Train accuracy: 0.7972535222182613
# Test set accuracy is:0.7817393892050738
# Epoch: 189, time taken: 319.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.552.
# At iteration 1000 the loss is 0.534.
# At iteration 1500 the loss is 0.660.
# At iteration 2000 the loss is 0.398.
# Train accuracy: 0.7973310187696647
# Test set accuracy is:0.7814790015995239
# Epoch: 190, time taken: 318.6s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.634.
# At iteration 1000 the loss is 0.342.
# At iteration 1500 the loss is 0.432.
# At iteration 2000 the loss is 0.429.
# Train accuracy: 0.7972845208388226
# Test set accuracy is:0.7816835918610274
# Epoch: 191, time taken: 319.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.459.
# At iteration 1000 the loss is 0.544.
# At iteration 1500 the loss is 0.512.
# At iteration 2000 the loss is 0.580.
# Train accuracy: 0.7974240146313489
# Test set accuracy is:0.7816463936316631
# Epoch: 192, time taken: 319.0s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.527.
# At iteration 1000 the loss is 0.561.
# At iteration 1500 the loss is 0.566.
# At iteration 2000 the loss is 0.594.
# Train accuracy: 0.7975557587687347
# Test set accuracy is:0.7816835918610274
# Epoch: 193, time taken: 319.4s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.564.
# At iteration 1000 the loss is 0.599.
# At iteration 1500 the loss is 0.489.
# At iteration 2000 the loss is 0.450.
# Train accuracy: 0.798098234628559
# Test set accuracy is:0.7815719971729346
# Epoch: 194, time taken: 320.5s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.530.
# At iteration 1000 the loss is 0.546.
# At iteration 1500 the loss is 0.507.
# At iteration 2000 the loss is 0.541.
# Train accuracy: 0.7978502456640679
# Test set accuracy is:0.7815719971729346
# Epoch: 195, time taken: 319.8s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.580.
# At iteration 1000 the loss is 0.602.
# At iteration 1500 the loss is 0.500.
# At iteration 2000 the loss is 0.521.
# Train accuracy: 0.7975402594584541
# Test set accuracy is:0.7815533980582524
# Epoch: 196, time taken: 320.0s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.471.
# At iteration 1000 the loss is 0.480.
# At iteration 1500 the loss is 0.518.
# At iteration 2000 the loss is 0.541.
# Train accuracy: 0.7975325098033138
# Test set accuracy is:0.781497600714206
# Epoch: 197, time taken: 319.1s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.615.
# At iteration 1000 the loss is 0.300.
# At iteration 1500 the loss is 0.564.
# At iteration 2000 the loss is 0.650.
# Train accuracy: 0.797873494629489
# Test set accuracy is:0.7815719971729346
# Epoch: 198, time taken: 320.0s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.645.
# At iteration 1000 the loss is 0.511.
# At iteration 1500 the loss is 0.397.
# At iteration 2000 the loss is 0.536.
# Train accuracy: 0.7978657449743486
# Test set accuracy is:0.781757988319756
# Epoch: 199, time taken: 322.7s, validation accuracy: 0.785.
# At iteration 500 the loss is 0.503.
# At iteration 1000 the loss is 0.598.
# At iteration 1500 the loss is 0.397.
# At iteration 2000 the loss is 0.707.
# Train accuracy: 0.7975325098033138
# Test set accuracy is:0.7814604024848417
# Epoch: 200, time taken: 321.1s, validation accuracy: 0.785.

# %% [markdown]
# Epoch 194 Test set accuracy is:0.7815719971729346, begins to fall after

# %%
training_lines(train_accuracies, valid_accuracies, max(test_accuracies), "Logistic Regression with original dataset")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Second Model using original dataset without duplicates

# %%
dataset_size = len(pd.read_csv(TRAIN_FILE2))
indices = list(range(dataset_size))
split = int(np.floor(validation_split*dataset_size))
train_indices, valid_indices = indices[split:], indices[:split]
train_sampler2 = SubsetRandomSampler(train_indices)
valid_sampler2 = SubsetRandomSampler(valid_indices)

# %%
train_dataloader2, valid_dataloader2 = get_dataloader(TRAIN_FILE2, BATCH_SIZE, SHUFFLE,
                                                    collate_fn, split=True, 
                                                    train_sample=train_sampler2,
                                                    valid_sample=valid_sampler2)
test_dataloader2 = get_dataloader(TEST_FILE2, BATCH_SIZE, SHUFFLE, collate_fn)

# %%
for idx, (lt, tt) in enumerate(train_dataloader2):
    print(lt.shape, tt.shape)
    if idx == 4: 
        input_d = tt.shape[1]
        break
input_dim = input_d
# Out:
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])

# %% [markdown]
# started 16:09. If one epoch takes 205 minutes, then 11.5 hours total. Finish at 3:39

# %%
model2 = LogisticRegression(input_dim, output_dim).to(device)
optimizer2 = torch.optim.Adam(model2.parameters(), lr=lr_rate)
loss_function = torch.nn.CrossEntropyLoss()
EPOCHS = 200
max_test_acc = 0

train_accuracies2 = []
valid_accuracies2=[]
test_accuracies2=[]
for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train_an_epoch(optimizer2, model2, train_dataloader2, loss_function)
    t_accuracy = get_accuracy(model2, train_dataloader2)
    train_accuracies2.append(t_accuracy)
    v_accuracy = get_accuracy(model2, valid_dataloader2)
    valid_accuracies2.append(v_accuracy)
    test_accuracy = get_accuracy(model2, test_dataloader2)
    print("Test set accuracy is:{}".format(test_accuracy))
    if test_accuracy > max_test_acc:
        max_test_acc = test_accuracy
        print("Epoch {} new highest test acc".format(epoch))
    test_accuracies2.append(test_accuracy)
    time_taken = time.time() - epoch_start_time
    print(f'Epoch: {epoch}, time taken: {time_taken:.1f}s, validation accuracy: {v_accuracy:.3f}.')
# Out:
# At iteration 500 the loss is 0.784.
# At iteration 1000 the loss is 0.875.
# Test set accuracy is:0.662359900373599
# Epoch 1 new highest test acc
# Epoch: 1, time taken: 203.0s, validation accuracy: 0.664.
# At iteration 500 the loss is 0.894.
# At iteration 1000 the loss is 0.905.
# Test set accuracy is:0.662640099626401
# Epoch 2 new highest test acc
# Epoch: 2, time taken: 204.3s, validation accuracy: 0.665.
# At iteration 500 the loss is 0.994.
# At iteration 1000 the loss is 0.747.
# Test set accuracy is:0.6635429638854297
# Epoch 3 new highest test acc
# Epoch: 3, time taken: 204.9s, validation accuracy: 0.666.
# At iteration 500 the loss is 0.858.
# At iteration 1000 the loss is 0.699.
# Test set accuracy is:0.6665940224159402
# Epoch 4 new highest test acc
# Epoch: 4, time taken: 206.3s, validation accuracy: 0.669.
# At iteration 500 the loss is 0.734.
# At iteration 1000 the loss is 0.816.
# Test set accuracy is:0.6701743462017434
# Epoch 5 new highest test acc
# Epoch: 5, time taken: 207.2s, validation accuracy: 0.673.
# At iteration 500 the loss is 0.758.
# At iteration 1000 the loss is 0.793.
# Test set accuracy is:0.6751556662515567
# Epoch 6 new highest test acc
# Epoch: 6, time taken: 207.1s, validation accuracy: 0.678.
# At iteration 500 the loss is 0.786.
# At iteration 1000 the loss is 0.881.
# Test set accuracy is:0.6800435865504358
# Epoch 7 new highest test acc
# Epoch: 7, time taken: 209.2s, validation accuracy: 0.682.
# At iteration 500 the loss is 0.692.
# At iteration 1000 the loss is 0.770.
# Test set accuracy is:0.6854607721046078
# Epoch 8 new highest test acc
# Epoch: 8, time taken: 207.4s, validation accuracy: 0.688.
# At iteration 500 the loss is 0.673.
# At iteration 1000 the loss is 0.832.
# Test set accuracy is:0.6925280199252802
# Epoch 9 new highest test acc
# Epoch: 9, time taken: 208.3s, validation accuracy: 0.696.
# At iteration 500 the loss is 0.629.
# At iteration 1000 the loss is 0.744.
# Test set accuracy is:0.6987546699875467
# Epoch 10 new highest test acc
# Epoch: 10, time taken: 208.6s, validation accuracy: 0.703.
# At iteration 500 the loss is 0.646.
# At iteration 1000 the loss is 0.610.
# Test set accuracy is:0.7021793275217932
# Epoch 11 new highest test acc
# Epoch: 11, time taken: 207.7s, validation accuracy: 0.706.
# At iteration 500 the loss is 0.739.
# At iteration 1000 the loss is 0.566.
# Test set accuracy is:0.7092465753424657
# Epoch 12 new highest test acc
# Epoch: 12, time taken: 209.0s, validation accuracy: 0.712.
# At iteration 500 the loss is 0.747.
# At iteration 1000 the loss is 0.700.
# Test set accuracy is:0.7130759651307597
# Epoch 13 new highest test acc
# Epoch: 13, time taken: 209.4s, validation accuracy: 0.716.
# At iteration 500 the loss is 0.774.
# At iteration 1000 the loss is 0.690.
# Test set accuracy is:0.7177459526774596
# Epoch 14 new highest test acc
# Epoch: 14, time taken: 209.4s, validation accuracy: 0.721.
# At iteration 500 the loss is 0.723.
# At iteration 1000 the loss is 0.735.
# Test set accuracy is:0.7186176836861768
# Epoch 15 new highest test acc
# Epoch: 15, time taken: 209.8s, validation accuracy: 0.722.
# At iteration 500 the loss is 0.574.
# At iteration 1000 the loss is 0.790.
# Test set accuracy is:0.7233810709838107
# Epoch 16 new highest test acc
# Epoch: 16, time taken: 210.4s, validation accuracy: 0.725.
# At iteration 500 the loss is 0.653.
# At iteration 1000 the loss is 0.715.
# Test set accuracy is:0.726681195516812
# Epoch 17 new highest test acc
# Epoch: 17, time taken: 210.5s, validation accuracy: 0.729.
# At iteration 500 the loss is 0.714.
# At iteration 1000 the loss is 0.811.
# Test set accuracy is:0.7289227895392278
# Epoch 18 new highest test acc
# Epoch: 18, time taken: 209.1s, validation accuracy: 0.731.
# At iteration 500 the loss is 0.496.
# At iteration 1000 the loss is 0.688.
# Test set accuracy is:0.7314134495641345
# Epoch 19 new highest test acc
# Epoch: 19, time taken: 208.9s, validation accuracy: 0.734.
# At iteration 500 the loss is 0.691.
# At iteration 1000 the loss is 0.565.
# Test set accuracy is:0.7334682440846825
# Epoch 20 new highest test acc
# Epoch: 20, time taken: 209.3s, validation accuracy: 0.736.
# At iteration 500 the loss is 0.605.
# At iteration 1000 the loss is 0.712.
# Test set accuracy is:0.7345267745952677
# Epoch 21 new highest test acc
# Epoch: 21, time taken: 208.7s, validation accuracy: 0.738.
# At iteration 500 the loss is 0.708.
# At iteration 1000 the loss is 0.699.
# Test set accuracy is:0.7371419676214197
# Epoch 22 new highest test acc
# Epoch: 22, time taken: 209.1s, validation accuracy: 0.741.
# At iteration 500 the loss is 0.660.
# At iteration 1000 the loss is 0.599.
# Test set accuracy is:0.7401618929016189
# Epoch 23 new highest test acc
# Epoch: 23, time taken: 209.2s, validation accuracy: 0.744.
# At iteration 500 the loss is 0.649.
# At iteration 1000 the loss is 0.503.
# Test set accuracy is:0.7369551681195516
# Epoch: 24, time taken: 209.2s, validation accuracy: 0.740.
# At iteration 500 the loss is 0.616.
# At iteration 1000 the loss is 0.652.
# Test set accuracy is:0.7426836861768369
# Epoch 25 new highest test acc
# Epoch: 25, time taken: 209.2s, validation accuracy: 0.745.
# At iteration 500 the loss is 0.588.
# At iteration 1000 the loss is 0.594.
# Test set accuracy is:0.7435242839352428
# Epoch 26 new highest test acc
# Epoch: 26, time taken: 208.9s, validation accuracy: 0.746.
# At iteration 500 the loss is 0.473.
# At iteration 1000 the loss is 0.655.
# Test set accuracy is:0.7467621419676215
# Epoch 27 new highest test acc
# Epoch: 27, time taken: 208.8s, validation accuracy: 0.748.
# At iteration 500 the loss is 0.707.
# At iteration 1000 the loss is 0.659.
# Test set accuracy is:0.7472914072229141
# Epoch 28 new highest test acc
# Epoch: 28, time taken: 208.5s, validation accuracy: 0.749.
# At iteration 500 the loss is 0.540.
# At iteration 1000 the loss is 0.642.
# Test set accuracy is:0.748038605230386
# Epoch 29 new highest test acc
# Epoch: 29, time taken: 209.4s, validation accuracy: 0.750.
# At iteration 500 the loss is 0.539.
# At iteration 1000 the loss is 0.636.
# Test set accuracy is:0.748318804483188
# Epoch 30 new highest test acc
# Epoch: 30, time taken: 208.9s, validation accuracy: 0.750.
# At iteration 500 the loss is 0.572.
# At iteration 1000 the loss is 0.559.
# Test set accuracy is:0.7500311332503113
# Epoch 31 new highest test acc
# Epoch: 31, time taken: 208.8s, validation accuracy: 0.751.
# At iteration 500 the loss is 0.620.
# At iteration 1000 the loss is 0.633.
# Test set accuracy is:0.750653798256538
# Epoch 32 new highest test acc
# Epoch: 32, time taken: 208.4s, validation accuracy: 0.752.
# At iteration 500 the loss is 0.638.
# At iteration 1000 the loss is 0.570.
# Test set accuracy is:0.7521481942714819
# Epoch 33 new highest test acc
# Epoch: 33, time taken: 209.0s, validation accuracy: 0.753.
# At iteration 500 the loss is 0.628.
# At iteration 1000 the loss is 0.570.
# Test set accuracy is:0.7532067247820673
# Epoch 34 new highest test acc
# Epoch: 34, time taken: 209.0s, validation accuracy: 0.754.
# At iteration 500 the loss is 0.617.
# At iteration 1000 the loss is 0.614.
# Test set accuracy is:0.75186799501868
# Epoch: 35, time taken: 209.0s, validation accuracy: 0.752.
# At iteration 500 the loss is 0.545.
# At iteration 1000 the loss is 0.560.
# Test set accuracy is:0.7537982565379826
# Epoch 36 new highest test acc
# Epoch: 36, time taken: 208.7s, validation accuracy: 0.754.
# At iteration 500 the loss is 0.591.
# At iteration 1000 the loss is 0.553.
# Test set accuracy is:0.7552926525529265
# Epoch 37 new highest test acc
# Epoch: 37, time taken: 208.9s, validation accuracy: 0.756.
# At iteration 500 the loss is 0.591.
# At iteration 1000 the loss is 0.648.
# Test set accuracy is:0.7553549190535492
# Epoch 38 new highest test acc
# Epoch: 38, time taken: 209.0s, validation accuracy: 0.756.
# At iteration 500 the loss is 0.610.
# At iteration 1000 the loss is 0.571.
# Test set accuracy is:0.7554483188044832
# Epoch 39 new highest test acc
# Epoch: 39, time taken: 208.3s, validation accuracy: 0.756.
# At iteration 500 the loss is 0.409.
# At iteration 1000 the loss is 0.569.
# Test set accuracy is:0.7558530510585305
# Epoch 40 new highest test acc
# Epoch: 40, time taken: 208.1s, validation accuracy: 0.756.
# At iteration 500 the loss is 0.603.
# At iteration 1000 the loss is 0.448.
# Test set accuracy is:0.7564134495641345
# Epoch 41 new highest test acc
# Epoch: 41, time taken: 208.2s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.481.
# At iteration 1000 the loss is 0.646.
# Test set accuracy is:0.7563200498132004
# Epoch: 42, time taken: 208.0s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.467.
# At iteration 1000 the loss is 0.507.
# Test set accuracy is:0.7572229140722292
# Epoch 43 new highest test acc
# Epoch: 43, time taken: 208.3s, validation accuracy: 0.758.
# At iteration 500 the loss is 0.458.
# At iteration 1000 the loss is 0.626.
# Test set accuracy is:0.7568181818181818
# Epoch: 44, time taken: 208.4s, validation accuracy: 0.758.
# At iteration 500 the loss is 0.518.
# At iteration 1000 the loss is 0.653.
# Test set accuracy is:0.7588107098381071
# Epoch 45 new highest test acc
# Epoch: 45, time taken: 208.3s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.641.
# At iteration 1000 the loss is 0.535.
# Test set accuracy is:0.7581569115815692
# Epoch: 46, time taken: 208.8s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.581.
# At iteration 1000 the loss is 0.546.
# Test set accuracy is:0.7580323785803238
# Epoch: 47, time taken: 208.2s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.553.
# At iteration 1000 the loss is 0.474.
# Test set accuracy is:0.7605230386052304
# Epoch 48 new highest test acc
# Epoch: 48, time taken: 209.0s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.469.
# At iteration 1000 the loss is 0.552.
# Test set accuracy is:0.760772104607721
# Epoch 49 new highest test acc
# Epoch: 49, time taken: 208.5s, validation accuracy: 0.762.
# At iteration 500 the loss is 0.620.
# At iteration 1000 the loss is 0.499.
# Test set accuracy is:0.759464508094645
# Epoch: 50, time taken: 210.4s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.547.
# At iteration 1000 the loss is 0.634.
# Test set accuracy is:0.7590286425902865
# Epoch: 51, time taken: 208.7s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.414.
# At iteration 1000 the loss is 0.483.
# Test set accuracy is:0.761425902864259
# Epoch 52 new highest test acc
# Epoch: 52, time taken: 208.4s, validation accuracy: 0.764.
# At iteration 500 the loss is 0.575.
# At iteration 1000 the loss is 0.522.
# Test set accuracy is:0.7621419676214197
# Epoch 53 new highest test acc
# Epoch: 53, time taken: 208.3s, validation accuracy: 0.764.
# At iteration 500 the loss is 0.447.
# At iteration 1000 the loss is 0.617.
# Test set accuracy is:0.7622353673723536
# Epoch 54 new highest test acc
# Epoch: 54, time taken: 209.0s, validation accuracy: 0.764.
# At iteration 500 the loss is 0.490.
# At iteration 1000 the loss is 0.506.
# Test set accuracy is:0.763013698630137
# Epoch 55 new highest test acc
# Epoch: 55, time taken: 208.2s, validation accuracy: 0.766.
# At iteration 500 the loss is 0.550.
# At iteration 1000 the loss is 0.528.
# Test set accuracy is:0.7617683686176837
# Epoch: 56, time taken: 208.1s, validation accuracy: 0.763.
# At iteration 500 the loss is 0.482.
# At iteration 1000 the loss is 0.624.
# Test set accuracy is:0.7628891656288916
# Epoch: 57, time taken: 209.3s, validation accuracy: 0.765.
# At iteration 500 the loss is 0.529.
# At iteration 1000 the loss is 0.630.
# Test set accuracy is:0.764134495641345
# Epoch 58 new highest test acc
# Epoch: 58, time taken: 209.1s, validation accuracy: 0.767.
# At iteration 500 the loss is 0.617.
# At iteration 1000 the loss is 0.559.
# Test set accuracy is:0.7634184308841843
# Epoch: 59, time taken: 210.3s, validation accuracy: 0.766.
# At iteration 500 the loss is 0.502.
# At iteration 1000 the loss is 0.624.
# Test set accuracy is:0.763574097135741
# Epoch: 60, time taken: 210.1s, validation accuracy: 0.766.
# At iteration 500 the loss is 0.551.
# At iteration 1000 the loss is 0.689.
# Test set accuracy is:0.7634184308841843
# Epoch: 61, time taken: 210.2s, validation accuracy: 0.766.
# At iteration 500 the loss is 0.708.
# At iteration 1000 the loss is 0.616.
# Test set accuracy is:0.7641656288916563
# Epoch 62 new highest test acc
# Epoch: 62, time taken: 210.2s, validation accuracy: 0.767.
# At iteration 500 the loss is 0.602.
# At iteration 1000 the loss is 0.573.
# Test set accuracy is:0.7646326276463262
# Epoch 63 new highest test acc
# Epoch: 63, time taken: 210.4s, validation accuracy: 0.768.
# At iteration 500 the loss is 0.507.
# At iteration 1000 the loss is 0.449.
# Test set accuracy is:0.763854296388543
# Epoch: 64, time taken: 210.4s, validation accuracy: 0.767.
# At iteration 500 the loss is 0.542.
# At iteration 1000 the loss is 0.473.
# Test set accuracy is:0.7649750933997509
# Epoch 65 new highest test acc
# Epoch: 65, time taken: 209.6s, validation accuracy: 0.768.
# At iteration 500 the loss is 0.605.
# At iteration 1000 the loss is 0.626.
# Test set accuracy is:0.7646637608966376
# Epoch: 66, time taken: 206.8s, validation accuracy: 0.768.
# At iteration 500 the loss is 0.674.
# At iteration 1000 the loss is 0.707.
# Test set accuracy is:0.7649439601494396
# Epoch: 67, time taken: 207.4s, validation accuracy: 0.768.
# At iteration 500 the loss is 0.619.
# At iteration 1000 the loss is 0.654.
# Test set accuracy is:0.765161892901619
# Epoch 68 new highest test acc
# Epoch: 68, time taken: 207.8s, validation accuracy: 0.769.
# At iteration 500 the loss is 0.743.
# At iteration 1000 the loss is 0.529.
# Test set accuracy is:0.7650996264009963
# Epoch: 69, time taken: 210.3s, validation accuracy: 0.769.
# At iteration 500 the loss is 0.553.
# At iteration 1000 the loss is 0.471.
# Test set accuracy is:0.7661892901618929
# Epoch 70 new highest test acc
# Epoch: 70, time taken: 210.3s, validation accuracy: 0.770.
# At iteration 500 the loss is 0.485.
# At iteration 1000 the loss is 0.716.
# Test set accuracy is:0.7655043586550436
# Epoch: 71, time taken: 205.8s, validation accuracy: 0.769.
# At iteration 500 the loss is 0.659.
# At iteration 1000 the loss is 0.448.
# Test set accuracy is:0.7667496886674969
# Epoch 72 new highest test acc
# Epoch: 72, time taken: 210.3s, validation accuracy: 0.770.
# At iteration 500 the loss is 0.673.
# At iteration 1000 the loss is 0.557.
# Test set accuracy is:0.7666251556662516
# Epoch: 73, time taken: 207.0s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.520.
# At iteration 1000 the loss is 0.476.
# Test set accuracy is:0.7665628891656289
# Epoch: 74, time taken: 209.0s, validation accuracy: 0.770.
# At iteration 500 the loss is 0.473.
# At iteration 1000 the loss is 0.595.
# Test set accuracy is:0.7676836861768369
# Epoch 75 new highest test acc
# Epoch: 75, time taken: 209.5s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.660.
# At iteration 1000 the loss is 0.514.
# Test set accuracy is:0.7666562889165629
# Epoch: 76, time taken: 210.4s, validation accuracy: 0.770.
# At iteration 500 the loss is 0.454.
# At iteration 1000 the loss is 0.563.
# Test set accuracy is:0.7667496886674969
# Epoch: 77, time taken: 211.3s, validation accuracy: 0.770.
# At iteration 500 the loss is 0.556.
# At iteration 1000 the loss is 0.615.
# Test set accuracy is:0.7670298879202989
# Epoch: 78, time taken: 209.8s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.479.
# At iteration 1000 the loss is 0.453.
# Test set accuracy is:0.7679638854296389
# Epoch 79 new highest test acc
# Epoch: 79, time taken: 209.6s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.552.
# At iteration 1000 the loss is 0.566.
# Test set accuracy is:0.7674346201743462
# Epoch: 80, time taken: 209.6s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.506.
# At iteration 1000 the loss is 0.599.
# Test set accuracy is:0.7669987546699876
# Epoch: 81, time taken: 208.2s, validation accuracy: 0.770.
# At iteration 500 the loss is 0.541.
# At iteration 1000 the loss is 0.656.
# Test set accuracy is:0.7670298879202989
# Epoch: 82, time taken: 207.3s, validation accuracy: 0.770.
# At iteration 500 the loss is 0.573.
# At iteration 1000 the loss is 0.611.
# Test set accuracy is:0.7680572851805728
# Epoch 83 new highest test acc
# Epoch: 83, time taken: 208.0s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.506.
# At iteration 1000 the loss is 0.629.
# Test set accuracy is:0.7684308841843088
# Epoch 84 new highest test acc
# Epoch: 84, time taken: 208.9s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.508.
# At iteration 1000 the loss is 0.524.
# Test set accuracy is:0.7681195516811955
# Epoch: 85, time taken: 209.4s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.609.
# At iteration 1000 the loss is 0.635.
# Test set accuracy is:0.7681506849315068
# Epoch: 86, time taken: 208.0s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.653.
# At iteration 1000 the loss is 0.685.
# Test set accuracy is:0.7687422166874222
# Epoch 87 new highest test acc
# Epoch: 87, time taken: 207.9s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.475.
# At iteration 1000 the loss is 0.647.
# Test set accuracy is:0.7683374844333748
# Epoch: 88, time taken: 206.7s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.558.
# At iteration 1000 the loss is 0.514.
# Test set accuracy is:0.7687422166874222
# Epoch: 89, time taken: 207.4s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.700.
# At iteration 1000 the loss is 0.475.
# Test set accuracy is:0.7683063511830636
# Epoch: 90, time taken: 206.8s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.542.
# At iteration 1000 the loss is 0.636.
# Test set accuracy is:0.7687733499377335
# Epoch 91 new highest test acc
# Epoch: 91, time taken: 207.0s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.717.
# At iteration 1000 the loss is 0.506.
# Test set accuracy is:0.7689601494396014
# Epoch 92 new highest test acc
# Epoch: 92, time taken: 206.8s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.505.
# At iteration 1000 the loss is 0.617.
# Test set accuracy is:0.7692403486924035
# Epoch 93 new highest test acc
# Epoch: 93, time taken: 207.0s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.531.
# At iteration 1000 the loss is 0.561.
# Test set accuracy is:0.7708281444582814
# Epoch 94 new highest test acc
# Epoch: 94, time taken: 206.8s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.467.
# At iteration 1000 the loss is 0.605.
# Test set accuracy is:0.7699875466998755
# Epoch: 95, time taken: 206.9s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.575.
# At iteration 1000 the loss is 0.521.
# Test set accuracy is:0.7697696139476962
# Epoch: 96, time taken: 206.9s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.460.
# At iteration 1000 the loss is 0.628.
# Test set accuracy is:0.7696450809464508
# Epoch: 97, time taken: 207.1s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.543.
# At iteration 1000 the loss is 0.504.
# Test set accuracy is:0.7701743462017434
# Epoch: 98, time taken: 208.0s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.404.
# At iteration 1000 the loss is 0.653.
# Test set accuracy is:0.7694582814445828
# Epoch: 99, time taken: 207.1s, validation accuracy: 0.771.
# At iteration 500 the loss is 0.517.
# At iteration 1000 the loss is 0.696.
# Test set accuracy is:0.7695205479452055
# Epoch: 100, time taken: 206.9s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.680.
# At iteration 1000 the loss is 0.508.
# Test set accuracy is:0.7702366127023661
# Epoch: 101, time taken: 206.6s, validation accuracy: 0.772.
# At iteration 500 the loss is 0.563.
# At iteration 1000 the loss is 0.532.
# Test set accuracy is:0.7716064757160648
# Epoch 102 new highest test acc
# Epoch: 102, time taken: 207.7s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.647.
# At iteration 1000 the loss is 0.520.
# Test set accuracy is:0.7710149439601495
# Epoch: 103, time taken: 207.8s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.517.
# At iteration 1000 the loss is 0.410.
# Test set accuracy is:0.7717621419676214
# Epoch 104 new highest test acc
# Epoch: 104, time taken: 207.4s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.506.
# At iteration 1000 the loss is 0.574.
# Test set accuracy is:0.7705479452054794
# Epoch: 105, time taken: 207.4s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.542.
# At iteration 1000 the loss is 0.435.
# Test set accuracy is:0.7706413449564135
# Epoch: 106, time taken: 207.6s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.521.
# At iteration 1000 the loss is 0.602.
# Test set accuracy is:0.7708592777085927
# Epoch: 107, time taken: 207.7s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.587.
# At iteration 1000 the loss is 0.462.
# Test set accuracy is:0.7711083437110834
# Epoch: 108, time taken: 207.9s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.591.
# At iteration 1000 the loss is 0.636.
# Test set accuracy is:0.7707036114570361
# Epoch: 109, time taken: 207.5s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.386.
# At iteration 1000 the loss is 0.739.
# Test set accuracy is:0.7710149439601495
# Epoch: 110, time taken: 207.3s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.499.
# At iteration 1000 the loss is 0.606.
# Test set accuracy is:0.7705168119551681
# Epoch: 111, time taken: 207.7s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.531.
# At iteration 1000 the loss is 0.595.
# Test set accuracy is:0.77173100871731
# Epoch: 112, time taken: 207.5s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.555.
# At iteration 1000 the loss is 0.503.
# Test set accuracy is:0.7713574097135741
# Epoch: 113, time taken: 207.4s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.567.
# At iteration 1000 the loss is 0.506.
# Test set accuracy is:0.7714508094645081
# Epoch: 114, time taken: 207.1s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.626.
# At iteration 1000 the loss is 0.556.
# Test set accuracy is:0.7712640099626401
# Epoch: 115, time taken: 207.6s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.568.
# At iteration 1000 the loss is 0.524.
# Test set accuracy is:0.7716687422166875
# Epoch: 116, time taken: 207.6s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.482.
# At iteration 1000 the loss is 0.605.
# Test set accuracy is:0.7719178082191781
# Epoch 117 new highest test acc
# Epoch: 117, time taken: 207.7s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.570.
# At iteration 1000 the loss is 0.770.
# Test set accuracy is:0.7729763387297633
# Epoch 118 new highest test acc
# Epoch: 118, time taken: 208.1s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.420.
# At iteration 1000 the loss is 0.510.
# Test set accuracy is:0.7729763387297633
# Epoch: 119, time taken: 208.2s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.489.
# At iteration 1000 the loss is 0.608.
# Test set accuracy is:0.772104607721046
# Epoch: 120, time taken: 207.2s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.613.
# At iteration 1000 the loss is 0.606.
# Test set accuracy is:0.7722914072229141
# Epoch: 121, time taken: 207.7s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.400.
# At iteration 1000 the loss is 0.498.
# Test set accuracy is:0.7720423412204234
# Epoch: 122, time taken: 208.0s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.554.
# At iteration 1000 the loss is 0.586.
# Test set accuracy is:0.7716687422166875
# Epoch: 123, time taken: 208.1s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.441.
# At iteration 1000 the loss is 0.401.
# Test set accuracy is:0.773412204234122
# Epoch 124 new highest test acc
# Epoch: 124, time taken: 208.2s, validation accuracy: 0.775.
# At iteration 500 the loss is 0.409.
# At iteration 1000 the loss is 0.386.
# Test set accuracy is:0.7722602739726028
# Epoch: 125, time taken: 207.6s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.580.
# At iteration 1000 the loss is 0.604.
# Test set accuracy is:0.7728829389788294
# Epoch: 126, time taken: 207.5s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.458.
# At iteration 1000 the loss is 0.641.
# Test set accuracy is:0.7742216687422167
# Epoch 127 new highest test acc
# Epoch: 127, time taken: 207.6s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.388.
# At iteration 1000 the loss is 0.524.
# Test set accuracy is:0.7737235367372354
# Epoch: 128, time taken: 207.7s, validation accuracy: 0.775.
# At iteration 500 the loss is 0.538.
# At iteration 1000 the loss is 0.633.
# Test set accuracy is:0.772945205479452
# Epoch: 129, time taken: 207.5s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.600.
# At iteration 1000 the loss is 0.683.
# Test set accuracy is:0.7733810709838107
# Epoch: 130, time taken: 207.5s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.467.
# At iteration 1000 the loss is 0.635.
# Test set accuracy is:0.7740037359900374
# Epoch: 131, time taken: 208.0s, validation accuracy: 0.775.
# At iteration 500 the loss is 0.498.
# At iteration 1000 the loss is 0.493.
# Test set accuracy is:0.7735367372353674
# Epoch: 132, time taken: 208.2s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.461.
# At iteration 1000 the loss is 0.500.
# Test set accuracy is:0.7730697384806974
# Epoch: 133, time taken: 209.3s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.506.
# At iteration 1000 the loss is 0.613.
# Test set accuracy is:0.7730697384806974
# Epoch: 134, time taken: 208.5s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.607.
# At iteration 1000 the loss is 0.533.
# Test set accuracy is:0.7731942714819428
# Epoch: 135, time taken: 208.3s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.508.
# At iteration 1000 the loss is 0.486.
# Test set accuracy is:0.7740037359900374
# Epoch: 136, time taken: 208.2s, validation accuracy: 0.775.
# At iteration 500 the loss is 0.478.
# At iteration 1000 the loss is 0.576.
# Test set accuracy is:0.773412204234122
# Epoch: 137, time taken: 208.3s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.391.
# At iteration 1000 the loss is 0.797.
# Test set accuracy is:0.7737546699875467
# Epoch: 138, time taken: 208.4s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.438.
# At iteration 1000 the loss is 0.651.
# Test set accuracy is:0.7731008717310087
# Epoch: 139, time taken: 207.9s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.395.
# At iteration 1000 the loss is 0.418.
# Test set accuracy is:0.7737235367372354
# Epoch: 140, time taken: 208.4s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.439.
# At iteration 1000 the loss is 0.439.
# Test set accuracy is:0.7742216687422167
# Epoch: 141, time taken: 209.1s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.525.
# At iteration 1000 the loss is 0.459.
# Test set accuracy is:0.773692403486924
# Epoch: 142, time taken: 208.7s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.569.
# At iteration 1000 the loss is 0.561.
# Test set accuracy is:0.7737235367372354
# Epoch: 143, time taken: 207.6s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.502.
# At iteration 1000 the loss is 0.610.
# Test set accuracy is:0.7737546699875467
# Epoch: 144, time taken: 207.9s, validation accuracy: 0.775.
# At iteration 500 the loss is 0.796.
# At iteration 1000 the loss is 0.676.
# Test set accuracy is:0.7735678704856787
# Epoch: 145, time taken: 208.0s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.584.
# At iteration 1000 the loss is 0.490.
# Test set accuracy is:0.7732565379825653
# Epoch: 146, time taken: 207.9s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.585.
# At iteration 1000 the loss is 0.561.
# Test set accuracy is:0.7741905354919053
# Epoch: 147, time taken: 208.0s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.554.
# At iteration 1000 the loss is 0.802.
# Test set accuracy is:0.7740037359900374
# Epoch: 148, time taken: 208.4s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.568.
# At iteration 1000 the loss is 0.662.
# Test set accuracy is:0.7740971357409714
# Epoch: 149, time taken: 207.3s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.483.
# At iteration 1000 the loss is 0.771.
# Test set accuracy is:0.773972602739726
# Epoch: 150, time taken: 208.3s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.546.
# At iteration 1000 the loss is 0.505.
# Test set accuracy is:0.77359900373599
# Epoch: 151, time taken: 207.9s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.475.
# At iteration 1000 the loss is 0.430.
# Test set accuracy is:0.7738480697384807
# Epoch: 152, time taken: 207.7s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.570.
# At iteration 1000 the loss is 0.349.
# Test set accuracy is:0.7740037359900374
# Epoch: 153, time taken: 207.9s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.672.
# At iteration 1000 the loss is 0.558.
# Test set accuracy is:0.7744084682440847
# Epoch 154 new highest test acc
# Epoch: 154, time taken: 207.3s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.543.
# At iteration 1000 the loss is 0.707.
# Test set accuracy is:0.7732254047322541
# Epoch: 155, time taken: 207.4s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.349.
# At iteration 1000 the loss is 0.624.
# Test set accuracy is:0.7740037359900374
# Epoch: 156, time taken: 207.8s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.424.
# At iteration 1000 the loss is 0.522.
# Test set accuracy is:0.7734744707347447
# Epoch: 157, time taken: 207.8s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.632.
# At iteration 1000 the loss is 0.537.
# Test set accuracy is:0.774719800747198
# Epoch 158 new highest test acc
# Epoch: 158, time taken: 208.0s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.400.
# At iteration 1000 the loss is 0.418.
# Test set accuracy is:0.774346201743462
# Epoch: 159, time taken: 207.9s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.417.
# At iteration 1000 the loss is 0.648.
# Test set accuracy is:0.77453300124533
# Epoch: 160, time taken: 206.9s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.472.
# At iteration 1000 the loss is 0.558.
# Test set accuracy is:0.7745952677459527
# Epoch: 161, time taken: 207.0s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.676.
# At iteration 1000 the loss is 0.476.
# Test set accuracy is:0.7740348692403487
# Epoch: 162, time taken: 207.5s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.395.
# At iteration 1000 the loss is 0.428.
# Test set accuracy is:0.7746575342465754
# Epoch: 163, time taken: 205.6s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.559.
# At iteration 1000 the loss is 0.637.
# Test set accuracy is:0.7747509339975094
# Epoch 164 new highest test acc
# Epoch: 164, time taken: 204.1s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.445.
# At iteration 1000 the loss is 0.628.
# Test set accuracy is:0.774252801992528
# Epoch: 165, time taken: 204.1s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.448.
# At iteration 1000 the loss is 0.751.
# Test set accuracy is:0.7746575342465754
# Epoch: 166, time taken: 206.1s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.592.
# At iteration 1000 the loss is 0.517.
# Test set accuracy is:0.7745952677459527
# Epoch: 167, time taken: 207.7s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.451.
# At iteration 1000 the loss is 0.435.
# Test set accuracy is:0.7746575342465754
# Epoch: 168, time taken: 208.1s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.499.
# At iteration 1000 the loss is 0.519.
# Test set accuracy is:0.7749688667496887
# Epoch 169 new highest test acc
# Epoch: 169, time taken: 207.8s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.425.
# At iteration 1000 the loss is 0.422.
# Test set accuracy is:0.7746575342465754
# Epoch: 170, time taken: 208.0s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.568.
# At iteration 1000 the loss is 0.558.
# Test set accuracy is:0.77453300124533
# Epoch: 171, time taken: 207.6s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.621.
# At iteration 1000 the loss is 0.387.
# Test set accuracy is:0.7747509339975094
# Epoch: 172, time taken: 207.7s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.570.
# At iteration 1000 the loss is 0.634.
# Test set accuracy is:0.7743773349937734
# Epoch: 173, time taken: 207.8s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.671.
# At iteration 1000 the loss is 0.473.
# Test set accuracy is:0.7747820672478207
# Epoch: 174, time taken: 207.7s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.545.
# At iteration 1000 the loss is 0.602.
# Test set accuracy is:0.7745018679950186
# Epoch: 175, time taken: 208.2s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.566.
# At iteration 1000 the loss is 0.512.
# Test set accuracy is:0.7741905354919053
# Epoch: 176, time taken: 207.8s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.532.
# At iteration 1000 the loss is 0.526.
# Test set accuracy is:0.7747820672478207
# Epoch: 177, time taken: 207.6s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.564.
# At iteration 1000 the loss is 0.500.
# Test set accuracy is:0.7749377334993773
# Epoch: 178, time taken: 207.8s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.468.
# At iteration 1000 the loss is 0.496.
# Test set accuracy is:0.774906600249066
# Epoch: 179, time taken: 208.1s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.600.
# At iteration 1000 the loss is 0.501.
# Test set accuracy is:0.7745018679950186
# Epoch: 180, time taken: 208.2s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.584.
# At iteration 1000 the loss is 0.486.
# Test set accuracy is:0.7749688667496887
# Epoch: 181, time taken: 210.0s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.537.
# At iteration 1000 the loss is 0.527.
# Test set accuracy is:0.7740348692403487
# Epoch: 182, time taken: 208.0s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.404.
# At iteration 1000 the loss is 0.647.
# Test set accuracy is:0.7745952677459527
# Epoch: 183, time taken: 207.9s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.571.
# At iteration 1000 the loss is 0.552.
# Test set accuracy is:0.7751556662515566
# Epoch 184 new highest test acc
# Epoch: 184, time taken: 207.6s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.468.
# At iteration 1000 the loss is 0.449.
# Test set accuracy is:0.7747509339975094
# Epoch: 185, time taken: 207.8s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.568.
# At iteration 1000 the loss is 0.490.
# Test set accuracy is:0.7750311332503114
# Epoch: 186, time taken: 207.8s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.402.
# At iteration 1000 the loss is 0.373.
# Test set accuracy is:0.7744396014943961
# Epoch: 187, time taken: 207.2s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.577.
# At iteration 1000 the loss is 0.572.
# Test set accuracy is:0.77453300124533
# Epoch: 188, time taken: 207.5s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.526.
# At iteration 1000 the loss is 0.401.
# Test set accuracy is:0.7748754669987546
# Epoch: 189, time taken: 207.2s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.341.
# At iteration 1000 the loss is 0.468.
# Test set accuracy is:0.7747509339975094
# Epoch: 190, time taken: 207.4s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.479.
# At iteration 1000 the loss is 0.538.
# Test set accuracy is:0.7741905354919053
# Epoch: 191, time taken: 207.5s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.500.
# At iteration 1000 the loss is 0.546.
# Test set accuracy is:0.7746886674968867
# Epoch: 192, time taken: 207.8s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.462.
# At iteration 1000 the loss is 0.502.
# Test set accuracy is:0.7747509339975094
# Epoch: 193, time taken: 208.2s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.525.
# At iteration 1000 the loss is 0.584.
# Test set accuracy is:0.7749377334993773
# Epoch: 194, time taken: 207.9s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.463.
# At iteration 1000 the loss is 0.319.
# Test set accuracy is:0.774719800747198
# Epoch: 195, time taken: 207.4s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.428.
# At iteration 1000 the loss is 0.454.
# Test set accuracy is:0.7745952677459527
# Epoch: 196, time taken: 208.0s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.436.
# At iteration 1000 the loss is 0.444.
# Test set accuracy is:0.774906600249066
# Epoch: 197, time taken: 208.7s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.396.
# At iteration 1000 the loss is 0.432.
# Test set accuracy is:0.7744707347447074
# Epoch: 198, time taken: 208.3s, validation accuracy: 0.773.
# At iteration 500 the loss is 0.629.
# At iteration 1000 the loss is 0.578.
# Test set accuracy is:0.7751245330012453
# Epoch: 199, time taken: 208.5s, validation accuracy: 0.774.
# At iteration 500 the loss is 0.514.
# At iteration 1000 the loss is 0.542.
# Test set accuracy is:0.7752490660024907
# Epoch 200 new highest test acc
# Epoch: 200, time taken: 208.5s, validation accuracy: 0.774.

# %% [markdown]
# Epoch 200 Test set accuracy is:0.7752490660024907

# %%
training_lines(train_accuracies2, valid_accuracies2, max(test_accuracies2), "Logistic Regression with original cleaned dataset")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Third model with cleaned dataset and newly scraped data

# %%
dataset_size = len(pd.read_csv(TRAIN_FILE3))
indices = list(range(dataset_size))
split = int(np.floor(validation_split*dataset_size))
train_indices, valid_indices = indices[split:], indices[:split]
train_sampler3 = SubsetRandomSampler(train_indices)
valid_sampler3 = SubsetRandomSampler(valid_indices)

# %%
train_dataloader3, valid_dataloader3 = get_dataloader(TRAIN_FILE3, BATCH_SIZE, SHUFFLE,
                                                    collate_fn, split=True, 
                                                    train_sample=train_sampler3,
                                                    valid_sample=valid_sampler3)
test_dataloader3 = get_dataloader(TEST_FILE3, BATCH_SIZE, SHUFFLE, collate_fn)

# %%
for idx, (lt, tt) in enumerate(train_dataloader3):
    print(lt.shape, tt.shape)
    if idx == 4: 
        input_d = tt.shape[1]
        break
input_dim = input_d
# Out:
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])
# torch.Size([64]) torch.Size([64, 4683])

# %% [markdown]
# started 6:40 ish

# %%
model3 = LogisticRegression(input_dim, output_dim).to(device)
optimizer3 = torch.optim.Adam(model3.parameters(), lr=lr_rate)
EPOCHS = 200
max_test_acc = 0

train_accuracies3 = []
valid_accuracies3 = []
test_accuracies3 = []
for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train_an_epoch(optimizer3, model3, train_dataloader3, loss_function)
    t_accuracy = get_accuracy(model3, train_dataloader3)
    train_accuracies3.append(t_accuracy)
    v_accuracy = get_accuracy(model3, valid_dataloader3)
    valid_accuracies3.append(v_accuracy)
    test_accuracy = get_accuracy(model3, test_dataloader3)
    print("Test set accuracy is:{}".format(test_accuracy))
    if test_accuracy > max_test_acc:
        max_test_acc = test_accuracy
        print("Epoch {} new highest test acc".format(epoch))
    test_accuracies3.append(test_accuracy)
    time_taken = time.time() - epoch_start_time
    print(f'Epoch: {epoch}, time taken: {time_taken:.1f}s, validation accuracy: {v_accuracy:.3f}.')
# Out:
# At iteration 500 the loss is 0.865.
# At iteration 1000 the loss is 0.760.
# At iteration 1500 the loss is 0.774.
# Test set accuracy is:0.6199351351351351
# Epoch 1 new highest test acc
# Epoch: 1, time taken: 301.5s, validation accuracy: 0.622.
# At iteration 500 the loss is 0.963.
# At iteration 1000 the loss is 0.775.
# At iteration 1500 the loss is 0.867.
# Test set accuracy is:0.623372972972973
# Epoch 2 new highest test acc
# Epoch: 2, time taken: 316.9s, validation accuracy: 0.625.
# At iteration 500 the loss is 0.843.
# At iteration 1000 the loss is 0.754.
# At iteration 1500 the loss is 0.885.
# Test set accuracy is:0.6328648648648648
# Epoch 3 new highest test acc
# Epoch: 3, time taken: 319.0s, validation accuracy: 0.634.
# At iteration 500 the loss is 0.854.
# At iteration 1000 the loss is 0.736.
# At iteration 1500 the loss is 0.746.
# Test set accuracy is:0.6469621621621622
# Epoch 4 new highest test acc
# Epoch: 4, time taken: 321.4s, validation accuracy: 0.648.
# At iteration 500 the loss is 0.872.
# At iteration 1000 the loss is 0.896.
# At iteration 1500 the loss is 0.699.
# Test set accuracy is:0.6609945945945946
# Epoch 5 new highest test acc
# Epoch: 5, time taken: 318.0s, validation accuracy: 0.662.
# At iteration 500 the loss is 0.768.
# At iteration 1000 the loss is 0.779.
# At iteration 1500 the loss is 0.721.
# Test set accuracy is:0.6698810810810811
# Epoch 6 new highest test acc
# Epoch: 6, time taken: 318.5s, validation accuracy: 0.672.
# At iteration 500 the loss is 0.676.
# At iteration 1000 the loss is 0.887.
# At iteration 1500 the loss is 0.761.
# Test set accuracy is:0.6809081081081081
# Epoch 7 new highest test acc
# Epoch: 7, time taken: 318.6s, validation accuracy: 0.683.
# At iteration 500 the loss is 0.870.
# At iteration 1000 the loss is 0.751.
# At iteration 1500 the loss is 0.772.
# Test set accuracy is:0.6888432432432432
# Epoch 8 new highest test acc
# Epoch: 8, time taken: 317.8s, validation accuracy: 0.692.
# At iteration 500 the loss is 0.663.
# At iteration 1000 the loss is 0.684.
# At iteration 1500 the loss is 0.794.
# Test set accuracy is:0.694118918918919
# Epoch 9 new highest test acc
# Epoch: 9, time taken: 313.3s, validation accuracy: 0.697.
# At iteration 500 the loss is 0.852.
# At iteration 1000 the loss is 0.790.
# At iteration 1500 the loss is 0.596.
# Test set accuracy is:0.7023135135135136
# Epoch 10 new highest test acc
# Epoch: 10, time taken: 310.4s, validation accuracy: 0.706.
# At iteration 500 the loss is 0.702.
# At iteration 1000 the loss is 0.743.
# At iteration 1500 the loss is 0.706.
# Test set accuracy is:0.7085405405405405
# Epoch 11 new highest test acc
# Epoch: 11, time taken: 313.7s, validation accuracy: 0.713.
# At iteration 500 the loss is 0.654.
# At iteration 1000 the loss is 0.791.
# At iteration 1500 the loss is 0.618.
# Test set accuracy is:0.7113513513513513
# Epoch 12 new highest test acc
# Epoch: 12, time taken: 310.2s, validation accuracy: 0.715.
# At iteration 500 the loss is 0.774.
# At iteration 1000 the loss is 0.735.
# At iteration 1500 the loss is 0.632.
# Test set accuracy is:0.7154594594594594
# Epoch 13 new highest test acc
# Epoch: 13, time taken: 311.2s, validation accuracy: 0.720.
# At iteration 500 the loss is 0.581.
# At iteration 1000 the loss is 0.665.
# At iteration 1500 the loss is 0.725.
# Test set accuracy is:0.7199567567567567
# Epoch 14 new highest test acc
# Epoch: 14, time taken: 311.1s, validation accuracy: 0.723.
# At iteration 500 the loss is 0.830.
# At iteration 1000 the loss is 0.680.
# At iteration 1500 the loss is 0.782.
# Test set accuracy is:0.7219675675675675
# Epoch 15 new highest test acc
# Epoch: 15, time taken: 312.0s, validation accuracy: 0.724.
# At iteration 500 the loss is 0.713.
# At iteration 1000 the loss is 0.797.
# At iteration 1500 the loss is 0.643.
# Test set accuracy is:0.7242810810810811
# Epoch 16 new highest test acc
# Epoch: 16, time taken: 316.4s, validation accuracy: 0.727.
# At iteration 500 the loss is 0.630.
# At iteration 1000 the loss is 0.723.
# At iteration 1500 the loss is 0.734.
# Test set accuracy is:0.7272216216216216
# Epoch 17 new highest test acc
# Epoch: 17, time taken: 302.3s, validation accuracy: 0.729.
# At iteration 500 the loss is 0.695.
# At iteration 1000 the loss is 0.704.
# At iteration 1500 the loss is 0.864.
# Test set accuracy is:0.728518918918919
# Epoch 18 new highest test acc
# Epoch: 18, time taken: 304.1s, validation accuracy: 0.731.
# At iteration 500 the loss is 0.566.
# At iteration 1000 the loss is 0.591.
# At iteration 1500 the loss is 0.747.
# Test set accuracy is:0.7295783783783784
# Epoch 19 new highest test acc
# Epoch: 19, time taken: 308.0s, validation accuracy: 0.732.
# At iteration 500 the loss is 0.666.
# At iteration 1000 the loss is 0.581.
# At iteration 1500 the loss is 0.697.
# Test set accuracy is:0.7309405405405406
# Epoch 20 new highest test acc
# Epoch: 20, time taken: 309.2s, validation accuracy: 0.733.
# At iteration 500 the loss is 0.576.
# At iteration 1000 the loss is 0.723.
# At iteration 1500 the loss is 0.840.
# Test set accuracy is:0.733145945945946
# Epoch 21 new highest test acc
# Epoch: 21, time taken: 311.9s, validation accuracy: 0.736.
# At iteration 500 the loss is 0.598.
# At iteration 1000 the loss is 0.612.
# At iteration 1500 the loss is 0.651.
# Test set accuracy is:0.733081081081081
# Epoch: 22, time taken: 313.0s, validation accuracy: 0.736.
# At iteration 500 the loss is 0.710.
# At iteration 1000 the loss is 0.414.
# At iteration 1500 the loss is 0.678.
# Test set accuracy is:0.7341621621621621
# Epoch 23 new highest test acc
# Epoch: 23, time taken: 310.2s, validation accuracy: 0.737.
# At iteration 500 the loss is 0.605.
# At iteration 1000 the loss is 0.623.
# At iteration 1500 the loss is 0.686.
# Test set accuracy is:0.735091891891892
# Epoch 24 new highest test acc
# Epoch: 24, time taken: 309.6s, validation accuracy: 0.738.
# At iteration 500 the loss is 0.594.
# At iteration 1000 the loss is 0.564.
# At iteration 1500 the loss is 0.676.
# Test set accuracy is:0.7352864864864865
# Epoch 25 new highest test acc
# Epoch: 25, time taken: 308.6s, validation accuracy: 0.739.
# At iteration 500 the loss is 0.590.
# At iteration 1000 the loss is 0.573.
# At iteration 1500 the loss is 0.544.
# Test set accuracy is:0.7377297297297297
# Epoch 26 new highest test acc
# Epoch: 26, time taken: 305.6s, validation accuracy: 0.741.
# At iteration 500 the loss is 0.727.
# At iteration 1000 the loss is 0.749.
# At iteration 1500 the loss is 0.751.
# Test set accuracy is:0.7398486486486486
# Epoch 27 new highest test acc
# Epoch: 27, time taken: 305.5s, validation accuracy: 0.742.
# At iteration 500 the loss is 0.589.
# At iteration 1000 the loss is 0.606.
# At iteration 1500 the loss is 0.703.
# Test set accuracy is:0.7403891891891892
# Epoch 28 new highest test acc
# Epoch: 28, time taken: 311.7s, validation accuracy: 0.744.
# At iteration 500 the loss is 0.587.
# At iteration 1000 the loss is 0.640.
# At iteration 1500 the loss is 0.802.
# Test set accuracy is:0.7396972972972973
# Epoch: 29, time taken: 312.8s, validation accuracy: 0.743.
# At iteration 500 the loss is 0.651.
# At iteration 1000 the loss is 0.638.
# At iteration 1500 the loss is 0.574.
# Test set accuracy is:0.7399567567567568
# Epoch: 30, time taken: 311.2s, validation accuracy: 0.743.
# At iteration 500 the loss is 0.768.
# At iteration 1000 the loss is 0.616.
# At iteration 1500 the loss is 0.547.
# Test set accuracy is:0.742054054054054
# Epoch 31 new highest test acc
# Epoch: 31, time taken: 310.8s, validation accuracy: 0.745.
# At iteration 500 the loss is 0.780.
# At iteration 1000 the loss is 0.617.
# At iteration 1500 the loss is 0.572.
# Test set accuracy is:0.7427027027027027
# Epoch 32 new highest test acc
# Epoch: 32, time taken: 314.4s, validation accuracy: 0.746.
# At iteration 500 the loss is 0.562.
# At iteration 1000 the loss is 0.624.
# At iteration 1500 the loss is 0.769.
# Test set accuracy is:0.7434810810810811
# Epoch 33 new highest test acc
# Epoch: 33, time taken: 310.5s, validation accuracy: 0.747.
# At iteration 500 the loss is 0.614.
# At iteration 1000 the loss is 0.558.
# At iteration 1500 the loss is 0.568.
# Test set accuracy is:0.7467891891891892
# Epoch 34 new highest test acc
# Epoch: 34, time taken: 305.5s, validation accuracy: 0.749.
# At iteration 500 the loss is 0.650.
# At iteration 1000 the loss is 0.554.
# At iteration 1500 the loss is 0.612.
# Test set accuracy is:0.7427459459459459
# Epoch: 35, time taken: 302.6s, validation accuracy: 0.747.
# At iteration 500 the loss is 0.540.
# At iteration 1000 the loss is 0.566.
# At iteration 1500 the loss is 0.676.
# Test set accuracy is:0.7420324324324324
# Epoch: 36, time taken: 299.9s, validation accuracy: 0.746.
# At iteration 500 the loss is 0.605.
# At iteration 1000 the loss is 0.682.
# At iteration 1500 the loss is 0.740.
# Test set accuracy is:0.7463783783783784
# Epoch: 37, time taken: 300.8s, validation accuracy: 0.749.
# At iteration 500 the loss is 0.540.
# At iteration 1000 the loss is 0.737.
# At iteration 1500 the loss is 0.669.
# Test set accuracy is:0.7461837837837838
# Epoch: 38, time taken: 304.8s, validation accuracy: 0.750.
# At iteration 500 the loss is 0.702.
# At iteration 1000 the loss is 0.680.
# At iteration 1500 the loss is 0.571.
# Test set accuracy is:0.7471567567567567
# Epoch 39 new highest test acc
# Epoch: 39, time taken: 308.2s, validation accuracy: 0.750.
# At iteration 500 the loss is 0.517.
# At iteration 1000 the loss is 0.728.
# At iteration 1500 the loss is 0.808.
# Test set accuracy is:0.7453189189189189
# Epoch: 40, time taken: 306.4s, validation accuracy: 0.749.
# At iteration 500 the loss is 0.776.
# At iteration 1000 the loss is 0.591.
# At iteration 1500 the loss is 0.607.
# Test set accuracy is:0.7461405405405406
# Epoch: 41, time taken: 303.0s, validation accuracy: 0.750.
# At iteration 500 the loss is 0.649.
# At iteration 1000 the loss is 0.445.
# At iteration 1500 the loss is 0.544.
# Test set accuracy is:0.7479567567567568
# Epoch 42 new highest test acc
# Epoch: 42, time taken: 302.6s, validation accuracy: 0.752.
# At iteration 500 the loss is 0.674.
# At iteration 1000 the loss is 0.638.
# At iteration 1500 the loss is 0.433.
# Test set accuracy is:0.7467243243243243
# Epoch: 43, time taken: 301.4s, validation accuracy: 0.750.
# At iteration 500 the loss is 0.581.
# At iteration 1000 the loss is 0.424.
# At iteration 1500 the loss is 0.619.
# Test set accuracy is:0.7475459459459459
# Epoch: 44, time taken: 300.3s, validation accuracy: 0.751.
# At iteration 500 the loss is 0.625.
# At iteration 1000 the loss is 0.554.
# At iteration 1500 the loss is 0.608.
# Test set accuracy is:0.7480864864864865
# Epoch 45 new highest test acc
# Epoch: 45, time taken: 299.5s, validation accuracy: 0.752.
# At iteration 500 the loss is 0.598.
# At iteration 1000 the loss is 0.615.
# At iteration 1500 the loss is 0.573.
# Test set accuracy is:0.7496864864864865
# Epoch 46 new highest test acc
# Epoch: 46, time taken: 300.3s, validation accuracy: 0.754.
# At iteration 500 the loss is 0.704.
# At iteration 1000 the loss is 0.746.
# At iteration 1500 the loss is 0.649.
# Test set accuracy is:0.7484108108108108
# Epoch: 47, time taken: 300.9s, validation accuracy: 0.752.
# At iteration 500 the loss is 0.830.
# At iteration 1000 the loss is 0.470.
# At iteration 1500 the loss is 0.624.
# Test set accuracy is:0.7509837837837838
# Epoch 48 new highest test acc
# Epoch: 48, time taken: 300.1s, validation accuracy: 0.754.
# At iteration 500 the loss is 0.570.
# At iteration 1000 the loss is 0.685.
# At iteration 1500 the loss is 0.537.
# Test set accuracy is:0.7493189189189189
# Epoch: 49, time taken: 300.3s, validation accuracy: 0.753.
# At iteration 500 the loss is 0.608.
# At iteration 1000 the loss is 0.696.
# At iteration 1500 the loss is 0.619.
# Test set accuracy is:0.7500108108108108
# Epoch: 50, time taken: 300.7s, validation accuracy: 0.754.
# At iteration 500 the loss is 0.529.
# At iteration 1000 the loss is 0.538.
# At iteration 1500 the loss is 0.639.
# Test set accuracy is:0.750572972972973
# Epoch: 51, time taken: 301.9s, validation accuracy: 0.754.
# At iteration 500 the loss is 0.659.
# At iteration 1000 the loss is 0.734.
# At iteration 1500 the loss is 0.658.
# Test set accuracy is:0.7505945945945945
# Epoch: 52, time taken: 303.2s, validation accuracy: 0.754.
# At iteration 500 the loss is 0.601.
# At iteration 1000 the loss is 0.704.
# At iteration 1500 the loss is 0.575.
# Test set accuracy is:0.7504432432432433
# Epoch: 53, time taken: 303.7s, validation accuracy: 0.754.
# At iteration 500 the loss is 0.731.
# At iteration 1000 the loss is 0.624.
# At iteration 1500 the loss is 0.580.
# Test set accuracy is:0.7504216216216216
# Epoch: 54, time taken: 303.0s, validation accuracy: 0.754.
# At iteration 500 the loss is 0.569.
# At iteration 1000 the loss is 0.773.
# At iteration 1500 the loss is 0.523.
# Test set accuracy is:0.7512648648648649
# Epoch 55 new highest test acc
# Epoch: 55, time taken: 302.6s, validation accuracy: 0.755.
# At iteration 500 the loss is 0.646.
# At iteration 1000 the loss is 0.633.
# At iteration 1500 the loss is 0.679.
# Test set accuracy is:0.7516108108108108
# Epoch 56 new highest test acc
# Epoch: 56, time taken: 303.6s, validation accuracy: 0.755.
# At iteration 500 the loss is 0.528.
# At iteration 1000 the loss is 0.638.
# At iteration 1500 the loss is 0.665.
# Test set accuracy is:0.7532972972972973
# Epoch 57 new highest test acc
# Epoch: 57, time taken: 298.6s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.523.
# At iteration 1000 the loss is 0.684.
# At iteration 1500 the loss is 0.565.
# Test set accuracy is:0.752345945945946
# Epoch: 58, time taken: 298.5s, validation accuracy: 0.756.
# At iteration 500 the loss is 0.621.
# At iteration 1000 the loss is 0.624.
# At iteration 1500 the loss is 0.536.
# Test set accuracy is:0.7526702702702702
# Epoch: 59, time taken: 299.0s, validation accuracy: 0.756.
# At iteration 500 the loss is 0.650.
# At iteration 1000 the loss is 0.701.
# At iteration 1500 the loss is 0.601.
# Test set accuracy is:0.7540756756756757
# Epoch 60 new highest test acc
# Epoch: 60, time taken: 297.6s, validation accuracy: 0.758.
# At iteration 500 the loss is 0.696.
# At iteration 1000 the loss is 0.511.
# At iteration 1500 the loss is 0.672.
# Test set accuracy is:0.7538594594594594
# Epoch: 61, time taken: 298.9s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.636.
# At iteration 1000 the loss is 0.538.
# At iteration 1500 the loss is 0.789.
# Test set accuracy is:0.7532540540540541
# Epoch: 62, time taken: 302.5s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.611.
# At iteration 1000 the loss is 0.573.
# At iteration 1500 the loss is 0.524.
# Test set accuracy is:0.7532108108108108
# Epoch: 63, time taken: 305.4s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.574.
# At iteration 1000 the loss is 0.618.
# At iteration 1500 the loss is 0.441.
# Test set accuracy is:0.7538378378378379
# Epoch: 64, time taken: 304.6s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.673.
# At iteration 1000 the loss is 0.662.
# At iteration 1500 the loss is 0.710.
# Test set accuracy is:0.7538810810810811
# Epoch: 65, time taken: 306.7s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.675.
# At iteration 1000 the loss is 0.619.
# At iteration 1500 the loss is 0.588.
# Test set accuracy is:0.7539027027027027
# Epoch: 66, time taken: 302.8s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.562.
# At iteration 1000 the loss is 0.638.
# At iteration 1500 the loss is 0.572.
# Test set accuracy is:0.7539243243243243
# Epoch: 67, time taken: 301.3s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.607.
# At iteration 1000 the loss is 0.475.
# At iteration 1500 the loss is 0.550.
# Test set accuracy is:0.7547459459459459
# Epoch 68 new highest test acc
# Epoch: 68, time taken: 301.9s, validation accuracy: 0.758.
# At iteration 500 the loss is 0.582.
# At iteration 1000 the loss is 0.653.
# At iteration 1500 the loss is 0.602.
# Test set accuracy is:0.7544216216216216
# Epoch: 69, time taken: 304.1s, validation accuracy: 0.757.
# At iteration 500 the loss is 0.601.
# At iteration 1000 the loss is 0.564.
# At iteration 1500 the loss is 0.685.
# Test set accuracy is:0.755718918918919
# Epoch 70 new highest test acc
# Epoch: 70, time taken: 309.2s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.510.
# At iteration 1000 the loss is 0.515.
# At iteration 1500 the loss is 0.592.
# Test set accuracy is:0.7549405405405405
# Epoch: 71, time taken: 308.8s, validation accuracy: 0.758.
# At iteration 500 the loss is 0.592.
# At iteration 1000 the loss is 0.695.
# At iteration 1500 the loss is 0.596.
# Test set accuracy is:0.7552432432432432
# Epoch: 72, time taken: 308.6s, validation accuracy: 0.758.
# At iteration 500 the loss is 0.679.
# At iteration 1000 the loss is 0.678.
# At iteration 1500 the loss is 0.530.
# Test set accuracy is:0.7555243243243244
# Epoch: 73, time taken: 306.3s, validation accuracy: 0.758.
# At iteration 500 the loss is 0.535.
# At iteration 1000 the loss is 0.566.
# At iteration 1500 the loss is 0.519.
# Test set accuracy is:0.7556324324324324
# Epoch: 74, time taken: 315.4s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.532.
# At iteration 1000 the loss is 0.746.
# At iteration 1500 the loss is 0.588.
# Test set accuracy is:0.7560864864864865
# Epoch 75 new highest test acc
# Epoch: 75, time taken: 310.9s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.663.
# At iteration 1000 the loss is 0.674.
# At iteration 1500 the loss is 0.525.
# Test set accuracy is:0.7563027027027027
# Epoch 76 new highest test acc
# Epoch: 76, time taken: 306.9s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.708.
# At iteration 1000 the loss is 0.500.
# At iteration 1500 the loss is 0.699.
# Test set accuracy is:0.7547459459459459
# Epoch: 77, time taken: 309.0s, validation accuracy: 0.758.
# At iteration 500 the loss is 0.617.
# At iteration 1000 the loss is 0.547.
# At iteration 1500 the loss is 0.592.
# Test set accuracy is:0.755827027027027
# Epoch: 78, time taken: 309.9s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.564.
# At iteration 1000 the loss is 0.514.
# At iteration 1500 the loss is 0.558.
# Test set accuracy is:0.7559567567567568
# Epoch: 79, time taken: 305.4s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.417.
# At iteration 1000 the loss is 0.607.
# At iteration 1500 the loss is 0.587.
# Test set accuracy is:0.7563243243243243
# Epoch 80 new highest test acc
# Epoch: 80, time taken: 300.5s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.537.
# At iteration 1000 the loss is 0.601.
# At iteration 1500 the loss is 0.569.
# Test set accuracy is:0.7569513513513514
# Epoch 81 new highest test acc
# Epoch: 81, time taken: 309.5s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.618.
# At iteration 1000 the loss is 0.698.
# At iteration 1500 the loss is 0.635.
# Test set accuracy is:0.7564756756756756
# Epoch: 82, time taken: 306.3s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.781.
# At iteration 1000 the loss is 0.664.
# At iteration 1500 the loss is 0.725.
# Test set accuracy is:0.756972972972973
# Epoch 83 new highest test acc
# Epoch: 83, time taken: 309.3s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.623.
# At iteration 1000 the loss is 0.690.
# At iteration 1500 the loss is 0.524.
# Test set accuracy is:0.7571891891891892
# Epoch 84 new highest test acc
# Epoch: 84, time taken: 310.7s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.737.
# At iteration 1000 the loss is 0.575.
# At iteration 1500 the loss is 0.498.
# Test set accuracy is:0.756627027027027
# Epoch: 85, time taken: 308.7s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.742.
# At iteration 1000 the loss is 0.455.
# At iteration 1500 the loss is 0.540.
# Test set accuracy is:0.755718918918919
# Epoch: 86, time taken: 307.6s, validation accuracy: 0.759.
# At iteration 500 the loss is 0.513.
# At iteration 1000 the loss is 0.538.
# At iteration 1500 the loss is 0.612.
# Test set accuracy is:0.7565837837837838
# Epoch: 87, time taken: 306.9s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.732.
# At iteration 1000 the loss is 0.581.
# At iteration 1500 the loss is 0.484.
# Test set accuracy is:0.757145945945946
# Epoch: 88, time taken: 308.4s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.551.
# At iteration 1000 the loss is 0.386.
# At iteration 1500 the loss is 0.512.
# Test set accuracy is:0.757427027027027
# Epoch 89 new highest test acc
# Epoch: 89, time taken: 307.0s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.791.
# At iteration 1000 the loss is 0.631.
# At iteration 1500 the loss is 0.669.
# Test set accuracy is:0.7577513513513513
# Epoch 90 new highest test acc
# Epoch: 90, time taken: 306.0s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.391.
# At iteration 1000 the loss is 0.597.
# At iteration 1500 the loss is 0.728.
# Test set accuracy is:0.7575135135135135
# Epoch: 91, time taken: 307.3s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.546.
# At iteration 1000 the loss is 0.441.
# At iteration 1500 the loss is 0.700.
# Test set accuracy is:0.7577081081081081
# Epoch: 92, time taken: 303.2s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.681.
# At iteration 1000 the loss is 0.515.
# At iteration 1500 the loss is 0.497.
# Test set accuracy is:0.7576432432432433
# Epoch: 93, time taken: 304.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.585.
# At iteration 1000 the loss is 0.650.
# At iteration 1500 the loss is 0.507.
# Test set accuracy is:0.7576432432432433
# Epoch: 94, time taken: 303.2s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.593.
# At iteration 1000 the loss is 0.580.
# At iteration 1500 the loss is 0.501.
# Test set accuracy is:0.7579027027027027
# Epoch 95 new highest test acc
# Epoch: 95, time taken: 298.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.656.
# At iteration 1000 the loss is 0.545.
# At iteration 1500 the loss is 0.652.
# Test set accuracy is:0.7568432432432433
# Epoch: 96, time taken: 297.8s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.523.
# At iteration 1000 the loss is 0.750.
# At iteration 1500 the loss is 0.611.
# Test set accuracy is:0.7573621621621621
# Epoch: 97, time taken: 297.2s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.557.
# At iteration 1000 the loss is 0.532.
# At iteration 1500 the loss is 0.377.
# Test set accuracy is:0.7583351351351352
# Epoch 98 new highest test acc
# Epoch: 98, time taken: 298.5s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.599.
# At iteration 1000 the loss is 0.656.
# At iteration 1500 the loss is 0.604.
# Test set accuracy is:0.7577297297297297
# Epoch: 99, time taken: 298.9s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.486.
# At iteration 1000 the loss is 0.426.
# At iteration 1500 the loss is 0.576.
# Test set accuracy is:0.7582054054054054
# Epoch: 100, time taken: 298.2s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.524.
# At iteration 1000 the loss is 0.580.
# At iteration 1500 the loss is 0.453.
# Test set accuracy is:0.7584432432432432
# Epoch 101 new highest test acc
# Epoch: 101, time taken: 297.6s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.726.
# At iteration 1000 the loss is 0.542.
# At iteration 1500 the loss is 0.582.
# Test set accuracy is:0.7587675675675676
# Epoch 102 new highest test acc
# Epoch: 102, time taken: 291.5s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.486.
# At iteration 1000 the loss is 0.696.
# At iteration 1500 the loss is 0.717.
# Test set accuracy is:0.7577513513513513
# Epoch: 103, time taken: 291.3s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.735.
# At iteration 1000 the loss is 0.594.
# At iteration 1500 the loss is 0.503.
# Test set accuracy is:0.7584432432432432
# Epoch: 104, time taken: 291.0s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.492.
# At iteration 1000 the loss is 0.677.
# At iteration 1500 the loss is 0.613.
# Test set accuracy is:0.7584432432432432
# Epoch: 105, time taken: 290.6s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.484.
# At iteration 1000 the loss is 0.796.
# At iteration 1500 the loss is 0.428.
# Test set accuracy is:0.7587675675675676
# Epoch: 106, time taken: 290.9s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.571.
# At iteration 1000 the loss is 0.430.
# At iteration 1500 the loss is 0.526.
# Test set accuracy is:0.7578810810810811
# Epoch: 107, time taken: 294.2s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.380.
# At iteration 1000 the loss is 0.472.
# At iteration 1500 the loss is 0.597.
# Test set accuracy is:0.7589621621621622
# Epoch 108 new highest test acc
# Epoch: 108, time taken: 292.4s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.774.
# At iteration 1000 the loss is 0.564.
# At iteration 1500 the loss is 0.528.
# Test set accuracy is:0.7580756756756757
# Epoch: 109, time taken: 292.0s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.631.
# At iteration 1000 the loss is 0.521.
# At iteration 1500 the loss is 0.485.
# Test set accuracy is:0.7587675675675676
# Epoch: 110, time taken: 292.5s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.415.
# At iteration 1000 the loss is 0.620.
# At iteration 1500 the loss is 0.595.
# Test set accuracy is:0.7589405405405405
# Epoch: 111, time taken: 293.4s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.493.
# At iteration 1000 the loss is 0.703.
# At iteration 1500 the loss is 0.599.
# Test set accuracy is:0.7592
# Epoch 112 new highest test acc
# Epoch: 112, time taken: 293.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.635.
# At iteration 1000 the loss is 0.647.
# At iteration 1500 the loss is 0.805.
# Test set accuracy is:0.7585081081081081
# Epoch: 113, time taken: 295.9s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.572.
# At iteration 1000 the loss is 0.520.
# At iteration 1500 the loss is 0.543.
# Test set accuracy is:0.7593081081081081
# Epoch 114 new highest test acc
# Epoch: 114, time taken: 295.6s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.475.
# At iteration 1000 the loss is 0.574.
# At iteration 1500 the loss is 0.519.
# Test set accuracy is:0.7592
# Epoch: 115, time taken: 295.8s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.888.
# At iteration 1000 the loss is 0.549.
# At iteration 1500 the loss is 0.549.
# Test set accuracy is:0.7592216216216217
# Epoch: 116, time taken: 295.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.688.
# At iteration 1000 the loss is 0.550.
# At iteration 1500 the loss is 0.643.
# Test set accuracy is:0.7590486486486486
# Epoch: 117, time taken: 295.2s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.459.
# At iteration 1000 the loss is 0.701.
# At iteration 1500 the loss is 0.494.
# Test set accuracy is:0.7581405405405406
# Epoch: 118, time taken: 295.2s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.465.
# At iteration 1000 the loss is 0.739.
# At iteration 1500 the loss is 0.531.
# Test set accuracy is:0.7595891891891892
# Epoch 119 new highest test acc
# Epoch: 119, time taken: 295.2s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.609.
# At iteration 1000 the loss is 0.560.
# At iteration 1500 the loss is 0.472.
# Test set accuracy is:0.7592864864864864
# Epoch: 120, time taken: 295.8s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.570.
# At iteration 1000 the loss is 0.630.
# At iteration 1500 the loss is 0.475.
# Test set accuracy is:0.7591783783783784
# Epoch: 121, time taken: 296.4s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.695.
# At iteration 1000 the loss is 0.570.
# At iteration 1500 the loss is 0.437.
# Test set accuracy is:0.7592648648648649
# Epoch: 122, time taken: 294.9s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.681.
# At iteration 1000 the loss is 0.598.
# At iteration 1500 the loss is 0.438.
# Test set accuracy is:0.7590270270270271
# Epoch: 123, time taken: 297.6s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.535.
# At iteration 1000 the loss is 0.741.
# At iteration 1500 the loss is 0.608.
# Test set accuracy is:0.7592
# Epoch: 124, time taken: 296.7s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.483.
# At iteration 1000 the loss is 0.660.
# At iteration 1500 the loss is 0.611.
# Test set accuracy is:0.7593945945945946
# Epoch: 125, time taken: 295.7s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.624.
# At iteration 1000 the loss is 0.513.
# At iteration 1500 the loss is 0.570.
# Test set accuracy is:0.7596324324324324
# Epoch 126 new highest test acc
# Epoch: 126, time taken: 297.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.580.
# At iteration 1000 the loss is 0.537.
# At iteration 1500 the loss is 0.684.
# Test set accuracy is:0.7588972972972973
# Epoch: 127, time taken: 296.1s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.590.
# At iteration 1000 the loss is 0.671.
# At iteration 1500 the loss is 0.618.
# Test set accuracy is:0.7592432432432432
# Epoch: 128, time taken: 296.2s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.531.
# At iteration 1000 the loss is 0.661.
# At iteration 1500 the loss is 0.662.
# Test set accuracy is:0.7600216216216216
# Epoch 129 new highest test acc
# Epoch: 129, time taken: 296.0s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.621.
# At iteration 1000 the loss is 0.684.
# At iteration 1500 the loss is 0.426.
# Test set accuracy is:0.7590918918918919
# Epoch: 130, time taken: 296.5s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.757.
# At iteration 1000 the loss is 0.547.
# At iteration 1500 the loss is 0.449.
# Test set accuracy is:0.7589189189189189
# Epoch: 131, time taken: 295.6s, validation accuracy: 0.760.
# At iteration 500 the loss is 0.485.
# At iteration 1000 the loss is 0.515.
# At iteration 1500 the loss is 0.580.
# Test set accuracy is:0.7592216216216217
# Epoch: 132, time taken: 295.7s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.568.
# At iteration 1000 the loss is 0.470.
# At iteration 1500 the loss is 0.710.
# Test set accuracy is:0.7591135135135135
# Epoch: 133, time taken: 296.8s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.555.
# At iteration 1000 the loss is 0.686.
# At iteration 1500 the loss is 0.699.
# Test set accuracy is:0.7590918918918919
# Epoch: 134, time taken: 296.2s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.524.
# At iteration 1000 the loss is 0.462.
# At iteration 1500 the loss is 0.538.
# Test set accuracy is:0.7591135135135135
# Epoch: 135, time taken: 295.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.707.
# At iteration 1000 the loss is 0.561.
# At iteration 1500 the loss is 0.539.
# Test set accuracy is:0.7598054054054054
# Epoch: 136, time taken: 294.4s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.649.
# At iteration 1000 the loss is 0.544.
# At iteration 1500 the loss is 0.735.
# Test set accuracy is:0.7591351351351351
# Epoch: 137, time taken: 295.4s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.453.
# At iteration 1000 the loss is 0.556.
# At iteration 1500 the loss is 0.755.
# Test set accuracy is:0.7601945945945946
# Epoch 138 new highest test acc
# Epoch: 138, time taken: 303.1s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.593.
# At iteration 1000 the loss is 0.631.
# At iteration 1500 the loss is 0.622.
# Test set accuracy is:0.7597837837837838
# Epoch: 139, time taken: 307.6s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.512.
# At iteration 1000 the loss is 0.498.
# At iteration 1500 the loss is 0.588.
# Test set accuracy is:0.7600864864864865
# Epoch: 140, time taken: 306.4s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.639.
# At iteration 1000 the loss is 0.726.
# At iteration 1500 the loss is 0.452.
# Test set accuracy is:0.7600432432432432
# Epoch: 141, time taken: 314.9s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.619.
# At iteration 1000 the loss is 0.437.
# At iteration 1500 the loss is 0.507.
# Test set accuracy is:0.7600648648648649
# Epoch: 142, time taken: 316.4s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.548.
# At iteration 1000 the loss is 0.565.
# At iteration 1500 the loss is 0.392.
# Test set accuracy is:0.7595675675675676
# Epoch: 143, time taken: 304.7s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.348.
# At iteration 1000 the loss is 0.485.
# At iteration 1500 the loss is 0.654.
# Test set accuracy is:0.7595891891891892
# Epoch: 144, time taken: 305.6s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.514.
# At iteration 1000 the loss is 0.513.
# At iteration 1500 the loss is 0.472.
# Test set accuracy is:0.7595243243243244
# Epoch: 145, time taken: 302.4s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.491.
# At iteration 1000 the loss is 0.607.
# At iteration 1500 the loss is 0.594.
# Test set accuracy is:0.7595675675675676
# Epoch: 146, time taken: 298.5s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.750.
# At iteration 1000 the loss is 0.518.
# At iteration 1500 the loss is 0.551.
# Test set accuracy is:0.7597837837837838
# Epoch: 147, time taken: 299.7s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.560.
# At iteration 1000 the loss is 0.563.
# At iteration 1500 the loss is 0.475.
# Test set accuracy is:0.7601513513513514
# Epoch: 148, time taken: 295.8s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.399.
# At iteration 1000 the loss is 0.760.
# At iteration 1500 the loss is 0.590.
# Test set accuracy is:0.7601729729729729
# Epoch: 149, time taken: 298.6s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.595.
# At iteration 1000 the loss is 0.694.
# At iteration 1500 the loss is 0.634.
# Test set accuracy is:0.7597621621621622
# Epoch: 150, time taken: 303.0s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.623.
# At iteration 1000 the loss is 0.563.
# At iteration 1500 the loss is 0.505.
# Test set accuracy is:0.7599351351351351
# Epoch: 151, time taken: 302.7s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.585.
# At iteration 1000 the loss is 0.635.
# At iteration 1500 the loss is 0.486.
# Test set accuracy is:0.7599567567567568
# Epoch: 152, time taken: 302.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.703.
# At iteration 1000 the loss is 0.561.
# At iteration 1500 the loss is 0.583.
# Test set accuracy is:0.7597837837837838
# Epoch: 153, time taken: 304.7s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.574.
# At iteration 1000 the loss is 0.509.
# At iteration 1500 the loss is 0.578.
# Test set accuracy is:0.7593945945945946
# Epoch: 154, time taken: 304.8s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.539.
# At iteration 1000 the loss is 0.567.
# At iteration 1500 the loss is 0.535.
# Test set accuracy is:0.7589621621621622
# Epoch: 155, time taken: 305.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.447.
# At iteration 1000 the loss is 0.613.
# At iteration 1500 the loss is 0.609.
# Test set accuracy is:0.7602594594594595
# Epoch 156 new highest test acc
# Epoch: 156, time taken: 304.1s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.469.
# At iteration 1000 the loss is 0.362.
# At iteration 1500 the loss is 0.642.
# Test set accuracy is:0.7599567567567568
# Epoch: 157, time taken: 305.5s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.608.
# At iteration 1000 the loss is 0.587.
# At iteration 1500 the loss is 0.527.
# Test set accuracy is:0.7595243243243244
# Epoch: 158, time taken: 303.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.717.
# At iteration 1000 the loss is 0.564.
# At iteration 1500 the loss is 0.570.
# Test set accuracy is:0.7605837837837838
# Epoch 159 new highest test acc
# Epoch: 159, time taken: 302.5s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.526.
# At iteration 1000 the loss is 0.519.
# At iteration 1500 the loss is 0.643.
# Test set accuracy is:0.7598918918918919
# Epoch: 160, time taken: 302.5s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.760.
# At iteration 1000 the loss is 0.674.
# At iteration 1500 the loss is 0.384.
# Test set accuracy is:0.7606918918918919
# Epoch 161 new highest test acc
# Epoch: 161, time taken: 307.6s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.446.
# At iteration 1000 the loss is 0.496.
# At iteration 1500 the loss is 0.559.
# Test set accuracy is:0.7601081081081081
# Epoch: 162, time taken: 307.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.628.
# At iteration 1000 the loss is 0.590.
# At iteration 1500 the loss is 0.629.
# Test set accuracy is:0.7592216216216217
# Epoch: 163, time taken: 315.0s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.546.
# At iteration 1000 the loss is 0.590.
# At iteration 1500 the loss is 0.521.
# Test set accuracy is:0.7592216216216217
# Epoch: 164, time taken: 321.9s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.516.
# At iteration 1000 the loss is 0.492.
# At iteration 1500 the loss is 0.358.
# Test set accuracy is:0.7597405405405405
# Epoch: 165, time taken: 309.1s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.558.
# At iteration 1000 the loss is 0.479.
# At iteration 1500 the loss is 0.534.
# Test set accuracy is:0.7604972972972973
# Epoch: 166, time taken: 307.5s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.723.
# At iteration 1000 the loss is 0.608.
# At iteration 1500 the loss is 0.543.
# Test set accuracy is:0.7599783783783783
# Epoch: 167, time taken: 307.3s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.481.
# At iteration 1000 the loss is 0.646.
# At iteration 1500 the loss is 0.522.
# Test set accuracy is:0.759481081081081
# Epoch: 168, time taken: 307.0s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.497.
# At iteration 1000 the loss is 0.434.
# At iteration 1500 the loss is 0.586.
# Test set accuracy is:0.7596108108108108
# Epoch: 169, time taken: 305.8s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.439.
# At iteration 1000 the loss is 0.480.
# At iteration 1500 the loss is 0.480.
# Test set accuracy is:0.7604972972972973
# Epoch: 170, time taken: 303.9s, validation accuracy: 0.761.
# At iteration 500 the loss is 0.452.
# At iteration 1000 the loss is 0.550.
# At iteration 1500 the loss is 0.730.

# %%
 training_lines(train_accuracies3, valid_accuracies3, max(test_accuracies3), "Logistic Regression with cleaned and enhanced dataset")

# %% [markdown]
# Highest test set accuracy epoch 161: 0.76
